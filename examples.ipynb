# %%
# !pip uninstall zonepy -y
# !pip install git+https://github.com/HOUPU1993/zonepy.git
# Out:
# Found existing installation: zonepy 0.5.0
# Uninstalling zonepy-0.5.0:
#   Successfully uninstalled zonepy-0.5.0
# Collecting git+https://github.com/HOUPU1993/zonepy.git
#   Cloning https://github.com/HOUPU1993/zonepy.git to /private/var/folders/s5/1g0kvw1x37z1n8xgxcp8f3lh0000gn/T/pip-req-build-u77na1gf
#   Running command git clone --filter=blob:none --quiet https://github.com/HOUPU1993/zonepy.git /private/var/folders/s5/1g0kvw1x37z1n8xgxcp8f3lh0000gn/T/pip-req-build-u77na1gf
#   Resolved https://github.com/HOUPU1993/zonepy.git to commit 17d4ba27475459dec4558ae2a0f0d01c8e693155
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: zonepy
#   Building wheel for zonepy (setup.py) ... done
#   Created wheel for zonepy: filename=zonepy-0.5.0-py3-none-any.whl size=32159 sha256=428228ba2877623e5c0441ac65651c402043a8467676a8854b170b966b57f0cb
#   Stored in directory: /private/var/folders/s5/1g0kvw1x37z1n8xgxcp8f3lh0000gn/T/pip-ephem-wheel-cache-dl820dcc/wheels/8d/11/20/938649b38af143c4dd31af716b45fc82ee9fda56102da41427
# Successfully built zonepy
# Installing collected packages: zonepy
# Successfully installed zonepy-0.5.0

# %%
# pip install pandas==2.1.4 geopandas==0.14.2

# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import json
import glob

from shapely.geometry import Point
from shapely.geometry import box
from shapely.geometry import mapping

from joblib import Parallel, delayed
from tqdm import tqdm

# input my libraries
from zonepy import zp_get_crs
from zonepy import zp_find_district_idx
from zonepy import zp_read_dist
from zonepy import zp_read_pcl
from zonepy import zp_read_bldg
from zonepy import zp_get_dist_def
from zonepy import zp_get_parcel_dim
from zonepy import zp_get_parcel_geo
from zonepy import zp_get_unit_info
from zonepy import zp_get_variables
from zonepy import zp_get_zoning_req
from zonepy import zp_check_unit
from zonepy import zp_check_res_type
from zonepy import zp_check_constraints
from zonepy import zp_add_setbacks
from zonepy import zp_get_buildable_area
from zonepy import zp_check_fit
from zonepy import possible_checks
from zonepy import zp_run_zoning_checks

# %% [markdown]
# # Re-construct the Data

# %%
# tidyparcel_feeds = tidyparcel_geo_feeds.merge(tidyparcel_dim_feeds[['parcel_id','lot_width','lot_depth','lot_area','confidence']], on='parcel_id', how='left')

# mask = tidyparcel_feeds['side'] != 'centroid'
# tidyparcel_feeds.loc[mask, ['lot_width','lot_depth','lot_area','confidence']] = np.nan

# unqiue_id = tidyparcel_feeds[tidyparcel_feeds['confidence'] == 'non_confidence_parcel']['parcel_id'].unique()
# tidyparcel_feeds.loc[(tidyparcel_feeds['parcel_id'].isin(unqiue_id)) & (tidyparcel_feeds['side'] != 'centroid'), 'side'] = 'Unknown'

# tidyparcel_feeds[['Prop_ID','parcel_id','parcel_label','side','lot_width','lot_depth','lot_area','geometry']].to_crs("EPSG:4326").to_file(r"/Users/houpuli/Dropbox/ceshi/tidyparcel_feeds.geojson", driver='GeoJSON')
# tidyparcel_feeds[tidyparcel_feeds['side'] == 'centroid'][['parcel_id','landuse','landuse_spec','confidence']].to_csv(r"/Users/houpuli/Dropbox/ceshi/tidyparcel_feeds_land_use.csv", index=False)

# %%
# tidyparcel_feeds = gpd.read_file(r"/Users/houpuli/Dropbox/ceshi/tidyparcel_feeds.geojson")
# tidyparcel_feeds

# %%
# # Example usage:
# process_all_districts(
#     tidyparcel_path="/Users/houpuli/Dropbox/ceshi/tidyparcel_feeds.geojson",
#     district_folder="/Users/houpuli/Dropbox/ceshi/ozfs_without_overlay/",
#     output_folder="/Users/houpuli/Dropbox/ceshi/tidyparcel_feeds/"
# )

# %% [markdown]
# # Step 1: some necessary functions
# For the functions of this part, you don't have to run them, because all of them were intergrated into the later functions, I list them here just for your reference.

# %% [markdown]
# ## `zp_get_crs` function
# Kamryn uploaded a state plane reference to [guihub](https://raw.githubusercontent.com/KamrynMansfield/tidyzoning/main/inst/extdata/sp_crs.geojson), and this function will refer you to get the correct crs of the geojson file. And this function is used in the `zp_read_pcl` function.

# %%
Addison_district = gpd.read_file(r"/Users/houpuli/Redlining Lab Dropbox/HOUPU LI/ceshi/tidyzonings/Addison.zoning")
print('The matched crs is EPSG:', zp_get_crs(Addison_district.loc[[0]]))
# Out:
# The matched crs is EPSG: 32138

# %% [markdown]
# # Step 2: Read files

# %% [markdown]
# ## 01.`zp_read_dist` function
# this function is for reading district info, and it will deleted those districts without valid geometry and re-index the structure, besides it will also auto-reproject the district data to the target crs by using "zp_get_crs" fucntion, while this function also allow you to input the target crs by yourself.

# %%
Addison_district = zp_read_dist(r"/Users/houpuli/Redlining Lab Dropbox/HOUPU LI/ceshi/tidyzonings/Addison.zoning", trans_crs=3857)
print("current crs is", Addison_district.crs)
Addison_district.head(5)
# Out:
# current crs is EPSG:3857
#                 dist_name dist_abbr  planned_dev  overlay  \
# 0  Single-Family Dwelling       R-1        False    False
# 3  Single-Family Dwelling      R-16        False    False
# 4      Apartment Dwelling         A        False    False
# 5            Local Retail        LR        False    False
# 6            Commercial-1       C-1        False    False
#
#                     res_types_allowed  \
# 0                            [1_unit]
# 3                            [1_unit]
# 4  [2_unit, 3_unit, 4_plus, townhome]
# 5                                 NaN
# 6                                 NaN
#
#                                          constraints  \
# 0  {'lot_size': {'min_val': [{'expression': ['0.2...
# 3  {'lot_size': {'min_val': [{'expression': ['0.3...
# 4  {'lot_size': {'min_val': [{'expression': ['1']...
# 5                                                NaN
# 6                                                NaN
#
#                                             geometry zoning_id
# 0  MULTIPOLYGON (((-10780184.101 3887684.743, -10...         0
# 3  MULTIPOLYGON (((-10777090.621 3888246.808, -10...         3
# 4  MULTIPOLYGON (((-10778516.328 3891864.967, -10...         4
# 5  MULTIPOLYGON (((-10781846.642 3887084.891, -10...         5
# 6  MULTIPOLYGON (((-10778798.181 3888383.694, -10...         6

# %%
Addison_district = zp_read_dist(r"/Users/houpuli/Redlining Lab Dropbox/HOUPU LI/ceshi/tidyzonings/Addison.zoning", trans_crs=None)
print("current crs is", Addison_district.crs)
Addison_district.head(5)
# Out:
# current crs is EPSG:32138
#                 dist_name dist_abbr  planned_dev  overlay  \
# 0  Single-Family Dwelling       R-1        False    False
# 3  Single-Family Dwelling      R-16        False    False
# 4      Apartment Dwelling         A        False    False
# 5            Local Retail        LR        False    False
# 6            Commercial-1       C-1        False    False
#
#                     res_types_allowed  \
# 0                            [1_unit]
# 3                            [1_unit]
# 4  [2_unit, 3_unit, 4_plus, townhome]
# 5                                 NaN
# 6                                 NaN
#
#                                          constraints  \
# 0  {'lot_size': {'min_val': [{'expression': ['0.2...
# 3  {'lot_size': {'min_val': [{'expression': ['0.3...
# 4  {'lot_size': {'min_val': [{'expression': ['1']...
# 5                                                NaN
# 6                                                NaN
#
#                                             geometry zoning_id
# 0  MULTIPOLYGON (((755203.329 2142711.882, 755202...         0
# 3  MULTIPOLYGON (((757793.793 2143223.087, 757790...         3
# 4  MULTIPOLYGON (((756548.273 2146227.618, 756547...         4
# 5  MULTIPOLYGON (((753814.918 2142188.501, 753814...         5
# 6  MULTIPOLYGON (((756357.973 2143314.560, 756354...         6

# %% [markdown]
# ## 02.`zp_read_pcl` function
# this funcion is for reading parcel info, and it will auto-match the same crs with the "district dataframe" created above(you cannot define the crs by yourself, because we must keep the same crs between "dist data" and "parcel_data", if you want to change the crs, you have define a crs by above "zp_read_dist" fucntion, and run "zp_read_pcl" fucntion again, and you will find the crs will change). Besides, this function will also add a "zoning_id" column to each parcel centroid row, which is the index of the district that contains the parcel centroid.

# %%
Addison_parcels = zp_read_pcl(r"/Users/houpuli/Redlining Lab Dropbox/HOUPU LI/ceshi/tidyparcel_feeds/Addison.parcel", Addison_district)
print("current crs is", Addison_parcels.crs)
Addison_parcels.head(5)
# Out:
# current crs is EPSG:32138
#                               parcel_id     side  lot_width  lot_depth  \
# 0  Dallas_County_combined_parcel_101985  unknown        NaN        NaN
# 1  Dallas_County_combined_parcel_101985  unknown        NaN        NaN
# 2  Dallas_County_combined_parcel_101985  unknown        NaN        NaN
# 3  Dallas_County_combined_parcel_101985  unknown        NaN        NaN
# 4  Dallas_County_combined_parcel_101985  unknown        NaN        NaN
#
#    lot_area                                           geometry zoning_id
# 0       NaN  LINESTRING (753828.148 2141685.199, 753833.116...       NaN
# 1       NaN  LINESTRING (753829.043 2141675.507, 753828.148...       NaN
# 2       NaN  LINESTRING (754035.787 2141676.898, 754034.848...       NaN
# 3       NaN  LINESTRING (754033.430 2141771.045, 754035.787...       NaN
# 4       NaN  LINESTRING (754000.588 2141799.274, 754033.430...       NaN

# %% [markdown]
# #### `zp_get_parcel_dim` function
# this funcion is for extracting all parcel dimension data("lot_width","lot_depth","lot_area") from original parcel data and correponding "parcel_id", besides, it will also split the parcel into two parts("corner" or "regular") by identidying whether "exterior side" exists or not.

# %%
zp_get_parcel_dim(Addison_parcels)
# Out:
#                                  parcel_id   lot_width   lot_depth  lot_area  \
# 0     Dallas_County_combined_parcel_101985    1.000000    1.000000  3.029635
# 1     Dallas_County_combined_parcel_102535  119.814881  208.678146  0.573980
# 2     Dallas_County_combined_parcel_103676    1.000000    1.000000  9.071160
# 3     Dallas_County_combined_parcel_103690    1.000000    1.000000  4.768296
# 4     Dallas_County_combined_parcel_103695    1.000000    1.000000  3.969046
# ...                                    ...         ...         ...       ...
# 2634   Dallas_County_combined_parcel_81817    1.000000    1.000000  0.094835
# 2635   Dallas_County_combined_parcel_81818    1.000000    1.000000  0.102011
# 2636   Dallas_County_combined_parcel_81819  124.065756  401.645015  1.136832
# 2637   Dallas_County_combined_parcel_81822  194.852130  391.729181  1.733046
# 2638   Dallas_County_combined_parcel_81827  149.901877  149.769582  0.513268
#
#      lot_type conf      side                        geometry zoning_id
# 0     regular   no  centroid  POINT (753967.508 2141717.861)        11
# 1     regular  yes  centroid  POINT (753782.051 2142205.528)   [5, 11]
# 2     regular   no  centroid  POINT (754270.641 2142313.614)        11
# 3     regular   no  centroid  POINT (754097.899 2141819.748)        11
# 4     regular   no  centroid  POINT (754134.798 2141749.830)        11
# ...       ...  ...       ...                             ...       ...
# 2634  regular   no  centroid  POINT (753801.562 2142827.307)        14
# 2635  regular   no  centroid  POINT (753783.314 2142828.596)        14
# 2636  regular  yes  centroid  POINT (753807.160 2142787.120)        27
# 2637   corner  yes  centroid  POINT (754036.944 2142596.153)         5
# 2638   corner  yes  centroid  POINT (753772.149 2142435.029)         5
#
# [2639 rows x 9 columns]

# %% [markdown]
# #### `zp_get_parcel_geo` function
# this funcion is for extracting all confident parcel geometry without "centroid" points, which is useful for later "zp_get_buildable_area" function and "zp_check_fit"

# %%
zp_get_parcel_geo(Addison_parcels)
# Out:
#                                  parcel_id           side  \
# 0     Dallas_County_combined_parcel_102535  interior side
# 1     Dallas_County_combined_parcel_102535           rear
# 2     Dallas_County_combined_parcel_102535  interior side
# 3     Dallas_County_combined_parcel_102535          front
# 4     Dallas_County_combined_parcel_104000  interior side
# ...                                    ...            ...
# 6500   Dallas_County_combined_parcel_81822  exterior side
# 6501   Dallas_County_combined_parcel_81827  exterior side
# 6502   Dallas_County_combined_parcel_81827          front
# 6503   Dallas_County_combined_parcel_81827  interior side
# 6504   Dallas_County_combined_parcel_81827           rear
#
#                                                geometry
# 0     LINESTRING (753814.050 2142187.387, 753750.347...
# 1     LINESTRING (753813.755 2142223.962, 753814.050...
# 2     LINESTRING (753750.053 2142223.668, 753813.755...
# 3     LINESTRING (753750.347 2142187.093, 753750.053...
# 4     LINESTRING (753824.836 2142394.500, 753824.880...
# ...                                                 ...
# 6500  LINESTRING (754066.019 2142655.691, 754066.948...
# 6501  LINESTRING (753795.082 2142412.365, 753749.363...
# 6502  LINESTRING (753749.363 2142412.121, 753749.279...
# 6503  LINESTRING (753749.279 2142457.881, 753794.999...
# 6504  LINESTRING (753794.999 2142457.749, 753795.082...
#
# [6505 rows x 3 columns]

# %% [markdown]
# ## 03.`zp_read_bldg` function
# this function is for reading preliminary building info, transferring json file into dictionary format, which is useful for "get_variables_function" later.

# %%
zp_read_bldg(r"/Users/houpuli/Redlining Lab Dropbox/HOUPU LI/ceshi/tidybuilding/4_fam_wide.bldg")
# Out:
# {'bldg_info': {'height_top': 38,
#   'height_plate': 37,
#   'roof_type': 'flat',
#   'width': 52,
#   'depth': 48,
#   'parking': 4,
#   'sep_platting': False},
#  'unit_info': [{'fl_area': 1108,
#    'bedrooms': 3,
#    'qty': 4,
#    'entry_level': 1,
#    'outside_entry': True}],
#  'level_info': [{'level': 1, 'gross_fl_area': 1534},
#   {'level': 2, 'gross_fl_area': 1533},
#   {'level': 3, 'gross_fl_area': 1533}]}

# %% [markdown]
# ## 04.`zp_get_dist_def` function
# this funcion is for extracting definition from the "district data" by input dist path, including "height" and "res_type".

# %%
zp_get_dist_def(r"/Users/houpuli/Redlining Lab Dropbox/HOUPU LI/ceshi/tidyzonings/Addison.zoning")
# Out:
# {'height': [{'condition': "roof_type == 'flat'", 'expression': 'height_top'},
#   {'condition': "roof_type == 'hip'",
#    'expression': '0.5 * (height_top + height_eave)'},
#   {'condition': "roof_type == 'mansard'", 'expression': 'height_deck'},
#   {'condition': "roof_type == 'gable'",
#    'expression': '0.5 * (height_top + height_eave)'},
#   {'condition': "roof_type == 'skillion'",
#    'expression': '0.5 * (height_top + height_eave)'},
#   {'condition': "roof_type == 'gambrel'",
#    'expression': '0.5 * (height_top + height_eave)'}],
#  'res_type': [{'condition': 'total_units == 1', 'expression': "'1_unit'"},
#   {'condition': 'total_units == 2', 'expression': "'2_unit'"},
#   {'condition': ['total_units > 2',
#     'n_outside_entry == total_units',
#     'n_ground_entry == total_units',
#     'sep_platting == TRUE'],
#    'expression': "'townhome'"},
#   {'condition': 'total_units == 3', 'expression': "'3_unit'"},
#   {'condition': 'total_units > 3', 'expression': "'4_plus'"}]}

# %% [markdown]
# # Functions

# %% [markdown]
# ## `zp_get_variables` function
# this function is for extracting and calculating building info by query data from dist info, and it will return a dataframe with all the variables you need, involving the "height" and "res_type" at the end of dataframe. The "bldg_data" and "zoning_data" can be input as dict or path, the "parcels_data" and "district_data" only can be geodataframe generated by`zp_read_pcl` and `zp_read_dist` functions.
# And this function will be intergrated into the `zp_get_zoning_req` function later.

# %%
bldg_data = zp_read_bldg(r"/Users/houpuli/Redlining Lab Dropbox/HOUPU LI/ceshi/tidybuilding/4_fam_wide.bldg")
parcel_dim = zp_get_parcel_dim(Addison_parcels)
parcel_data = parcel_dim[parcel_dim['parcel_id'] == 'Dallas_County_combined_parcel_51626']
district_data = Addison_district.loc[[13]]
dist_def = zp_get_dist_def(r"/Users/houpuli/Redlining Lab Dropbox/HOUPU LI/ceshi/tidyzonings/Addison.zoning")
vars = zp_get_variables(bldg_data, parcel_data, district_data, dist_def)

# %%
vars = zp_get_variables(bldg_data, parcel_data, district_data, dist_def)
vars
# Out:
#    bldg_depth  bldg_width dist_abbr  fl_area  fl_area_first  fl_area_top  \
# 0          48          52      PDCC     4600           1534         1533
#
#    floors  height_deck  height_eave  height_plate  ...  unit_pct_1bed  \
# 0       3           38           38            37  ...            0.0
#
#    unit_pct_2bed  unit_pct_3bed  unit_pct_4bed  unit_size_avg lot_cov_bldg  \
# 0            0.0            1.0            0.0         1108.0   206.838276
#
#    unit_density       far  height  res_type
# 0    144.389027  3.811923      38    4_plus
#
# [1 rows x 42 columns]

# %%
vars = zp_get_variables(r'/Users/houpuli/Redlining Lab Dropbox/HOUPU LI/ceshi/tidybuilding/4_fam_wide.bldg',parcel_data, district_data, r'/Users/houpuli/Redlining Lab Dropbox/HOUPU LI/ceshi/tidyzonings/Addison.zoning')
vars
# Out:
#    bldg_depth  bldg_width dist_abbr  fl_area  fl_area_first  fl_area_top  \
# 0          48          52      PDCC     4600           1534         1533
#
#    floors  height_deck  height_eave  height_plate  ...  unit_pct_1bed  \
# 0       3           38           38            37  ...            0.0
#
#    unit_pct_2bed  unit_pct_3bed  unit_pct_4bed  unit_size_avg lot_cov_bldg  \
# 0            0.0            1.0            0.0         1108.0   206.838276
#
#    unit_density       far  height  res_type
# 0    144.389027  3.811923      38    4_plus
#
# [1 rows x 42 columns]

# %% [markdown]
# ## `zp_get_zoning_req` function
# this function is for calculating specific zoning requirements based on the provided extracting variables and district data. It returns a DataFrame containing the constraints for each district, including variables such as "setback", "lot_coverage", and "height"(not including "unit_size", we have another function `check_unit`for that).

# %%
bldg_data = zp_read_bldg(r"/Users/houpuli/Redlining Lab Dropbox/HOUPU LI/ceshi/tidybuilding/4_fam_wide.bldg")
parcel_dim = zp_get_parcel_dim(Addison_parcels)
parcel_data = parcel_dim[parcel_dim['parcel_id'] == 'Dallas_County_combined_parcel_51626']
district_data = Addison_district.loc[[13]]
dist_def = zp_get_dist_def(r"/Users/houpuli/Redlining Lab Dropbox/HOUPU LI/ceshi/tidyzonings/Addison.zoning")
vars = zp_get_variables(bldg_data, parcel_data, district_data, dist_def)

# %%
district_data.iloc[0]['constraints']
# Out:
# {'parking_uncovered': {'min_val': [{'expression': ['1 * total_units']}]}}

# %%
zoning_req = zp_get_zoning_req(district_data, bldg_data, parcel_data, dist_def)
zoning_req
# Out:
#      constraint_name  min_value max_value min_val_error max_val_error
# 0  parking_uncovered        4.0      None          None          None

# %%
zoning_req = zp_get_zoning_req(district_data, bldg_data=None, parcel_data=None, zoning_data=None, vars=vars)
zoning_req
# Out:
#      constraint_name  min_value max_value min_val_error max_val_error
# 0  parking_uncovered        4.0      None          None          None

# %% [markdown]
# ## `zp_check_unit` function
# this function is for extracting bedrooms and corresponding fl_area in each unit. And it will check whether the unit is fit for the zoning requirements, and return a DataFrame with the results.

# %%
bldg_data = zp_read_bldg(r"/Users/houpuli/Redlining Lab Dropbox/HOUPU LI/ceshi/tidybuilding/4_fam_wide.bldg")
parcel_dim = zp_get_parcel_dim(Addison_parcels)
parcel_data = parcel_dim[parcel_dim['parcel_id'] == 'Dallas_County_combined_parcel_51626']
district_data = Addison_district.loc[[13]]
dist_def = zp_get_dist_def(r"/Users/houpuli/Redlining Lab Dropbox/HOUPU LI/ceshi/tidyzonings/Addison.zoning")
vars = zp_get_variables(bldg_data, parcel_data, district_data, dist_def)

# %%
Addison_district.loc[13]['constraints']
# Out:
# {'parking_uncovered': {'min_val': [{'expression': ['1 * total_units']}]}}

# %%
zp_check_unit(district_data, bldg_data, vars)
# Out:
# True

# %% [markdown]
# ## `zp_check_res_type` function
# this function is for checking whether the building is allowed by district use_type?

# %%
zp_check_res_type(vars, district_data)
# Out:
# True

# %% [markdown]
# ## `zp_check_constraints` function
# this function is for checking whether the variables is allowed by zoning requirements.

# %%
zp_check_constraints(vars, zoning_req, checks=['lot_cov_bldg'])
# Out:
# Empty DataFrame
# Columns: [constraint_name, allowed]
# Index: []

# %%
zp_check_constraints(vars, zoning_req, checks=None)
# Out:
# Empty DataFrame
# Columns: [constraint_name, allowed]
# Index: []

# %% [markdown]
# ## `zp_add_setbacks` function
# assign setback info of each zoning req to the parcel geo data, which is useful for later "zp_get_buildable_area" function.

# %%
Addison_district.iloc[1]['constraints']
# Out:
# {'lot_size': {'min_val': [{'expression': ['0.37']}]},
#  'setback_front': {'min_val': [{'expression': ['35']}]},
#  'setback_side_int': {'min_val': [{'expression': ['10']}]},
#  'setback_side_ext': {'min_val': [{'expression': ['35']}]},
#  'setback_rear': {'min_val': [{'min_max': 'max',
#     'expression': ['20', '0.2 * lot_depth']}]},
#  'setback_side_sum': {'min_val': [{'expression': ['0.1 * lot_width']}]},
#  'parking_uncovered': {'min_val': [{'expression': ['2 * total_units']}]},
#  'stories': {'max_val': [{'expression': ['2.5']}]},
#  'height': {'max_val': [{'expression': ['29']}]},
#  'unit_size': {'min_val': [{'expression': ['1000']}]}}

# %%
bldg_data = zp_read_bldg(r"/Users/houpuli/Redlining Lab Dropbox/HOUPU LI/ceshi/tidybuilding/4_fam_wide.bldg")
parcel_dim = zp_get_parcel_dim(Addison_parcels)
parcel_data = parcel_dim[parcel_dim['parcel_id'] == 'Dallas_County_combined_parcel_47099']
district_data = Addison_district.iloc[[1]]
dist_def = zp_get_dist_def(r"/Users/houpuli/Redlining Lab Dropbox/HOUPU LI/ceshi/tidyzonings/Addison.zoning")
vars = zp_get_variables(bldg_data, parcel_data, district_data, dist_def)

# %%
zoning_req = zp_get_zoning_req(district_data, bldg_data=None, parcel_data=None, zoning_data=None, vars=vars)
parcel_geo = zp_get_parcel_geo(Addison_parcels)
parcel_geo_data = parcel_geo[parcel_geo['parcel_id'] == 'Dallas_County_combined_parcel_47099']

# %%
parcel_geo[parcel_geo['parcel_id'] == 'Dallas_County_combined_parcel_47099']
# Out:
#                                parcel_id           side  \
# 158  Dallas_County_combined_parcel_47099           rear
# 159  Dallas_County_combined_parcel_47099          front
# 160  Dallas_County_combined_parcel_47099  interior side
# 161  Dallas_County_combined_parcel_47099  exterior side
#
#                                               geometry
# 158  LINESTRING (757789.418 2143366.543, 757776.048...
# 159  LINESTRING (757808.354 2143416.348, 757821.979...
# 160  LINESTRING (757835.531 2143367.098, 757789.418...
# 161  LINESTRING (757776.048 2143397.154, 757799.528...

# %%
Addison_parcels[Addison_parcels['zoning_id'] == '3']
# Out:
#                                   parcel_id      side   lot_width   lot_depth  \
# 367     Dallas_County_combined_parcel_46778  centroid    1.000000    1.000000
# 434     Dallas_County_combined_parcel_47049  centroid    1.000000    1.000000
# 482     Dallas_County_combined_parcel_47060  centroid    1.000000    1.000000
# 499     Dallas_County_combined_parcel_47063  centroid    1.000000    1.000000
# 525     Dallas_County_combined_parcel_47072  centroid    1.000000    1.000000
# 535     Dallas_County_combined_parcel_47078  centroid  233.151343  184.676341
# 549     Dallas_County_combined_parcel_47082  centroid    1.000000    1.000000
# 556     Dallas_County_combined_parcel_47083  centroid    1.000000    1.000000
# 571     Dallas_County_combined_parcel_47088  centroid  183.869851  207.877859
# 576     Dallas_County_combined_parcel_47089  centroid  149.252049  157.446120
# 598     Dallas_County_combined_parcel_47099  centroid  190.334175  151.067999
# 603     Dallas_County_combined_parcel_47101  centroid  245.263756  134.866901
# 640     Dallas_County_combined_parcel_47113  centroid  162.764309  176.471613
# 684     Dallas_County_combined_parcel_47809  centroid  135.198361  160.224128
# 708     Dallas_County_combined_parcel_47815  centroid    1.000000    1.000000
# 713     Dallas_County_combined_parcel_47816  centroid  145.259610  145.830492
# 732     Dallas_County_combined_parcel_47819  centroid    1.000000    1.000000
# 773     Dallas_County_combined_parcel_47833  centroid  136.434893  151.802500
# 783     Dallas_County_combined_parcel_47840  centroid  212.973624  197.718969
# 881     Dallas_County_combined_parcel_47875  centroid    1.000000    1.000000
# 914     Dallas_County_combined_parcel_47883  centroid    1.000000    1.000000
# 1324    Dallas_County_combined_parcel_48311  centroid    1.000000    1.000000
# 1351    Dallas_County_combined_parcel_48315  centroid    1.000000    1.000000
# 1388    Dallas_County_combined_parcel_48321  centroid   90.681474  232.654983
# 1393    Dallas_County_combined_parcel_48322  centroid   96.552537  226.609136
# 1408    Dallas_County_combined_parcel_48325  centroid  136.175090  166.589619
# 1453    Dallas_County_combined_parcel_48341  centroid  168.169341  147.134001
# 1470    Dallas_County_combined_parcel_48345  centroid  206.065227  188.168395
# 1494    Dallas_County_combined_parcel_48354  centroid    1.000000    1.000000
# 1499    Dallas_County_combined_parcel_48357  centroid  249.718542  299.221766
# 1520    Dallas_County_combined_parcel_48365  centroid    1.000000    1.000000
# 1534    Dallas_County_combined_parcel_48369  centroid    1.000000    1.000000
# 1621    Dallas_County_combined_parcel_48388  centroid    1.000000    1.000000
# 1628    Dallas_County_combined_parcel_48389  centroid    1.000000    1.000000
# 1684    Dallas_County_combined_parcel_48689  centroid  186.474965  197.526972
# 1768    Dallas_County_combined_parcel_48717  centroid    1.000000    1.000000
# 1802    Dallas_County_combined_parcel_48732  centroid  161.751493  135.292375
# 1813    Dallas_County_combined_parcel_48739  centroid  123.929430  192.809958
# 1992    Dallas_County_combined_parcel_48888  centroid    1.000000    1.000000
# 2048    Dallas_County_combined_parcel_48900  centroid  116.631568  183.093588
# 2118    Dallas_County_combined_parcel_48922  centroid    1.000000    1.000000
# 2146    Dallas_County_combined_parcel_48934  centroid  144.512996  209.787724
# 2163    Dallas_County_combined_parcel_48938  centroid    1.000000    1.000000
# 2189    Dallas_County_combined_parcel_48959  centroid    1.000000    1.000000
# 2194    Dallas_County_combined_parcel_48960  centroid  134.992628  171.456223
# 5988   Dallas_County_combined_parcel_596025  centroid    1.000000    1.000000
# 14521   Dallas_County_combined_parcel_72374  centroid  248.886595  388.120653
# 14550   Dallas_County_combined_parcel_72377  centroid    1.000000    1.000000
# 14560   Dallas_County_combined_parcel_72379  centroid  153.150175  147.495106
# 14577   Dallas_County_combined_parcel_72382  centroid  107.090093  205.989068
# 14650   Dallas_County_combined_parcel_72395  centroid  148.037993  136.456168
# 14668   Dallas_County_combined_parcel_72398  centroid  130.200289  191.395729
# 14673   Dallas_County_combined_parcel_72401  centroid  154.323121  157.468197
# 14679   Dallas_County_combined_parcel_72402  centroid  206.942785  189.201257
# 14697   Dallas_County_combined_parcel_72408  centroid    1.000000    1.000000
# 14703   Dallas_County_combined_parcel_72409  centroid    1.000000    1.000000
#
#        lot_area                        geometry zoning_id
# 367    0.925468  POINT (757875.777 2143842.623)         3
# 434    0.684610  POINT (757808.405 2143875.710)         3
# 482    0.459006  POINT (757870.791 2143664.287)         3
# 499    0.500415  POINT (757866.623 2143630.891)         3
# 525    0.583361  POINT (757627.141 2143553.110)         3
# 535    0.543397  POINT (757616.557 2143509.992)         3
# 549    0.385860  POINT (757768.908 2143501.220)         3
# 556    0.475972  POINT (757812.394 2143503.401)         3
# 571    0.485048  POINT (757747.320 2143461.751)         3
# 576    0.424260  POINT (757802.628 2143464.769)         3
# 598    0.494659  POINT (757806.417 2143387.494)         3
# 603    0.495592  POINT (757769.901 2143360.718)         3
# 640    0.642775  POINT (757782.567 2143259.487)         3
# 684    0.449767  POINT (757803.517 2143649.126)         3
# 708    0.485670  POINT (757801.931 2143559.520)         3
# 713    0.454057  POINT (757713.747 2143561.445)         3
# 732    0.481118  POINT (757867.385 2143543.281)         3
# 773    0.453188  POINT (757705.535 2143463.266)         3
# 783    0.495621  POINT (757665.471 2143408.847)         3
# 881    1.324408  POINT (757825.730 2143161.242)         3
# 914    2.054287  POINT (758000.148 2143127.351)         3
# 1324   0.806664  POINT (757877.852 2143977.518)         3
# 1351   0.470605  POINT (757870.210 2143896.046)         3
# 1388   0.475273  POINT (757814.581 2143778.176)         3
# 1393   0.472525  POINT (757812.186 2143750.224)         3
# 1408   0.482593  POINT (757873.822 2143701.659)         3
# 1453   0.515753  POINT (757869.042 2143498.341)         3
# 1470   0.453654  POINT (757616.490 2143455.966)         3
# 1494   0.482146  POINT (757775.574 2143433.731)         3
# 1499   0.565940  POINT (757720.331 2143408.017)         3
# 1520   0.460382  POINT (757810.763 2143344.519)         3
# 1534   0.499305  POINT (757870.359 2143318.882)         3
# 1621   0.970273  POINT (757905.420 2143133.314)         3
# 1628   0.906387  POINT (757944.323 2143123.229)         3
# 1684   0.507856  POINT (757887.080 2143791.991)         3
# 1768   0.963310  POINT (757863.434 2143398.605)         3
# 1802   0.483574  POINT (757774.315 2143311.794)         3
# 1813   0.526343  POINT (757867.916 2143257.687)         3
# 1992   0.521103  POINT (757864.821 2143931.754)         3
# 2048   0.449934  POINT (757806.353 2143686.677)         3
# 2118   0.387701  POINT (757688.789 2143508.549)         3
# 2146   0.509486  POINT (757863.060 2143452.990)         3
# 2163   0.570284  POINT (757627.053 2143417.710)         3
# 2189   0.490603  POINT (757826.978 2143305.094)         3
# 2194   0.524045  POINT (757827.797 2143260.095)         3
# 5988   1.204801  POINT (757872.388 2143164.339)         3
# 14521  1.695188  POINT (757806.157 2143955.294)         3
# 14550  0.874011  POINT (757808.810 2143822.254)         3
# 14560  0.472160  POINT (757878.336 2143744.748)         3
# 14577  0.461854  POINT (757809.543 2143719.925)         3
# 14650  0.440118  POINT (757801.322 2143606.180)         3
# 14668  0.499056  POINT (757865.519 2143580.772)         3
# 14673  0.530259  POINT (757758.606 2143559.798)         3
# 14679  0.490291  POINT (757666.731 2143563.438)         3
# 14697  0.374914  POINT (757729.187 2143503.771)         3
# 14703  0.440205  POINT (757668.863 2143475.118)         3

# %%
zoning_req
# Out:
#      constraint_name  min_value  max_value min_val_error max_val_error
# 0           lot_size     0.3700        NaN          None          None
# 1      setback_front    35.0000        NaN          None          None
# 2   setback_side_int    10.0000        NaN          None          None
# 3   setback_side_ext    35.0000        NaN          None          None
# 4       setback_rear    30.2136        NaN          None          None
# 5   setback_side_sum    19.0334        NaN          None          None
# 6  parking_uncovered     8.0000        NaN          None          None
# 7            stories        NaN        2.5          None          None
# 8             height        NaN       29.0          None          None

# %%
parcel_geo_data
# Out:
#                                parcel_id           side  \
# 158  Dallas_County_combined_parcel_47099           rear
# 159  Dallas_County_combined_parcel_47099          front
# 160  Dallas_County_combined_parcel_47099  interior side
# 161  Dallas_County_combined_parcel_47099  exterior side
#
#                                               geometry
# 158  LINESTRING (757789.418 2143366.543, 757776.048...
# 159  LINESTRING (757808.354 2143416.348, 757821.979...
# 160  LINESTRING (757835.531 2143367.098, 757789.418...
# 161  LINESTRING (757776.048 2143397.154, 757799.528...

# %%
parcels_with_setbacks = zp_add_setbacks(parcel_geo_data, district_data, zoning_req)
parcels_with_setbacks
# Out:
#                                parcel_id           side  \
# 158  Dallas_County_combined_parcel_47099           rear
# 159  Dallas_County_combined_parcel_47099          front
# 160  Dallas_County_combined_parcel_47099  interior side
# 161  Dallas_County_combined_parcel_47099  exterior side
#
#                                               geometry    setback
# 158  LINESTRING (757789.418 2143366.543, 757776.048...    30.2136
# 159  LINESTRING (757808.354 2143416.348, 757821.979...       35.0
# 160  LINESTRING (757835.531 2143367.098, 757789.418...  [10.0, 0]
# 161  LINESTRING (757776.048 2143397.154, 757799.528...       35.0

# %% [markdown]
# ## `zp_get_buildable_area` function
# assign setback info of each zoning req to the parcel geo data, which is useful for later "zp_get_buildable_area" function.

# %%
buildable_area = zp_get_buildable_area(parcels_with_setbacks)
buildable_area
# Out:
#                              parcel_id buildable_geometry_relaxable  \
# 0  Dallas_County_combined_parcel_51626                POLYGON EMPTY
#
#   buildable_geometry_strict
# 0             POLYGON EMPTY

# %%
import matplotlib.pyplot as plt
import matplotlib.lines as mlines

# Define a mapping from 'side' values to colors.
color_mapping = {
    'Interior side': 'red',
    'Exterior side': 'blue',
    'rear': 'green',
    'front': 'orange'
}

fig, ax = plt.subplots(figsize=(10, 10))

# Plot the setbacks results by grouping based on the 'side' column.
for side, group in parcels_with_setbacks.groupby('side'):
    group.plot(
        ax=ax, 
        color=None, 
        alpha=1, 
        edgecolor=color_mapping.get(side, 'black'), 
        linewidth=5, 
        label=f'Parcels with setbacks ({side})'
    )

# Plot the strict buildable area.
strict_area = buildable_area.copy().set_geometry('buildable_geometry_strict')
strict_area.plot(
    ax=ax, 
    color='red', 
    alpha=0.5, 
    edgecolor='black', 
    label='Strict Buildable Area'
)

# Plot the relaxable buildable area.
relaxable_area = buildable_area.copy().set_geometry('buildable_geometry_relaxable')
relaxable_area.plot(
    ax=ax, 
    color='blue', 
    alpha=0.5, 
    edgecolor='black', 
    label='Relaxable Buildable Area'
)

# Create custom legend handles.
handles = []
# Add legend handles for each setbacks side.
for side in parcels_with_setbacks['side'].unique():
    color = color_mapping.get(side, 'black')
    handle = mlines.Line2D([], [], color=color, linewidth=5, label=f'Parcels with setbacks ({side})')
    handles.append(handle)
# Add handles for the buildable area layers.
handles.append(mlines.Line2D([], [], color='red', marker='s', markersize=10,
                             markerfacecolor='red', linestyle='None',
                             label='Strict Buildable Area'))
handles.append(mlines.Line2D([], [], color='blue', marker='s', markersize=10,
                             markerfacecolor='blue', linestyle='None',
                             label='Relaxable Buildable Area'))

ax.legend(handles=handles, loc='upper right', bbox_to_anchor=(2.2, 1))
plt.show()

# %% [markdown]
# ## `zp_check_fit` function
# check whether the building footprint can fit into the parcel buildable_area.

# %%
zp_check_fit(buildable_area, vars)
# Out:
#                              parcel_id  allowed
# 0  Dallas_County_combined_parcel_51626    False

# %% [markdown]
# ## `zp_run_zoning_checks` function
# check whether the building footprint can fit into the parcel buildable_area.

# %%
zp_read_dist(r'/Users/houpuli/Redlining Lab Dropbox/HOUPU LI/ceshi/test/Cockrell Hill.zoning')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 zp_read_dist(r'/Users/houpuli/Redlining Lab Dropbox/HOUPU LI/ceshi/test/Cockrell Hill.zoning')
#
# File /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/zonepy/zp_read_dist.py:37, in zp_read_dist(path, trans_crs, index_col)
#      35     target_crs = trans_crs
#      36 else:
# ---> 37     auto_epsg = zp_get_crs(path, large_area=False)
#      38     target_crs = f"EPSG:{auto_epsg}"
#      40 # 3. Reproject to the target CRS
#
# File /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/zonepy/zp_get_crs.py:69, in zp_get_crs(geom_data, large_area)
#      66 joined = gpd.sjoin(geom, state_planes_crs, how="inner", predicate="intersects")
#      68 if joined.empty:
# ---> 69     raise ValueError(
#      70         "No intersection found with any State Plane zone."
#      71     )
#      73 # Count how many times each state plane index appears
#      74 counts = joined["index_right"].value_counts()
#
# ValueError: No intersection found with any State Plane zone.

# %%
ceshi = gpd.read_file(r'/Users/houpuli/Redlining Lab Dropbox/HOUPU LI/ceshi/test/Cockrell Hill.zoning')
ceshi
# Out:
#              dist_name dist_abbr  planned_dev  overlay  \
# 0          Residential         R        False    False
# 1        Single-Family       R-S        False    False
# 2      Multiple-Family       R-M        False    False
# 3           Commercial         C        False    False
# 4           Commercial       C-A        False    False
# 5  Planned Development        PD         True    False
#
#                                    res_types_allowed  \
# 0                                                NaN
# 1                        [single_family, two_family]
# 2  [single_family, two_family, multiple_family, t...
# 3  [single_family, two_family, multiple_family, t...
# 4                                                NaN
# 5                                                NaN
#
#                                          constraints  \
# 0                                                NaN
# 1  {'lot_area': {'min_val': [{'expression': '0.16...
# 2  {'lot_area': {'min_val': [{'expression': '0.16...
# 3  {'lot_area': {'min_val': [{'expression': '0.16...
# 4                                                NaN
# 5                                                NaN
#
#                                             geometry
# 0                                               None
# 1  MULTIPOLYGON (((-96.87971 32.73877, -96.87970 ...
# 2  MULTIPOLYGON (((-96.88145 32.73920, -96.88165 ...
# 3  MULTIPOLYGON (((-96.87860 32.73980, -96.87859 ...
# 4  MULTIPOLYGON (((-96.87949 32.73959, -96.87950 ...
# 5                                               None

# %%
ceshi.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7381326f50931e3c29a17b72dda19a92 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7381326f50931e3c29a17b72dda19a92&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7381326f50931e3c29a17b72dda19a92 = L.map(
#                 &quot;map_7381326f50931e3c29a17b72dda19a92&quot;,
#                 {
#                     center: [32.73884534950005, -96.8884868365],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_7381326f50931e3c29a17b72dda19a92);
#
#
#
#
#
#             var tile_layer_2fa078709ab9d7ff2d10f7bdcdecc3de = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2fa078709ab9d7ff2d10f7bdcdecc3de.addTo(map_7381326f50931e3c29a17b72dda19a92);
#
#
#             map_7381326f50931e3c29a17b72dda19a92.fitBounds(
#                 [[32.731589899, -96.898382263], [32.7461008000001, -96.87859141]],
#                 {}
#             );
#
#
#         function geo_json_db6547180605e0976d0f19f20399b2ef_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_db6547180605e0976d0f19f20399b2ef_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_db6547180605e0976d0f19f20399b2ef_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_db6547180605e0976d0f19f20399b2ef_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_db6547180605e0976d0f19f20399b2ef_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_db6547180605e0976d0f19f20399b2ef.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_db6547180605e0976d0f19f20399b2ef_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_db6547180605e0976d0f19f20399b2ef = L.geoJson(null, {
#                 onEachFeature: geo_json_db6547180605e0976d0f19f20399b2ef_onEachFeature,
#
#                 style: geo_json_db6547180605e0976d0f19f20399b2ef_styler,
#                 pointToLayer: geo_json_db6547180605e0976d0f19f20399b2ef_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_db6547180605e0976d0f19f20399b2ef_add (data) {
#             geo_json_db6547180605e0976d0f19f20399b2ef
#                 .addData(data);
#         }
#             geo_json_db6547180605e0976d0f19f20399b2ef_add({&quot;bbox&quot;: [-96.898382263, 32.731589899, -96.87859141, 32.7461008000001], &quot;features&quot;: [{&quot;bbox&quot;: [-96.898382263, 32.731589899, -96.879701939, 32.7461008000001], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-96.879713102, 32.738767249], [-96.879701939, 32.7391762660001], [-96.879908381, 32.7391786220001], [-96.88010344, 32.7391808400001], [-96.8803015889999, 32.739183091], [-96.880496518, 32.7391853290001], [-96.8806947319999, 32.739187584], [-96.880838376, 32.739189222], [-96.880882605, 32.7391897270001], [-96.880895391, 32.7387293690001], [-96.8807009179999, 32.7387271380001], [-96.880506022, 32.7387249010001], [-96.880309989, 32.7387226490001], [-96.880111841, 32.7387203700001], [-9

# %%
ceshi2 = gpd.read_file("https://raw.githubusercontent.com/KamrynMansfield/tidyzoning/main/inst/extdata/sp_crs.geojson")

# %%
ceshi2
# Out:
#      OBJECTID  ZONE       ZONENAME  EPSG_NAD83  \
# 0           1  HI_1  Hawaii Zone 1       26961
# 1           2  HI_2  Hawaii Zone 2       26962
# 2           3  HI_3  Hawaii Zone 3       26963
# 3           4  HI_4  Hawaii Zone 4       26964
# 4           5  HI_5  Hawaii Zone 5       26965
# ..        ...   ...            ...         ...
# 116       117  AK_4  Alaska Zone 4       26934
# 117       118  AK_3  Alaska Zone 3       26933
# 118       119  AK_2  Alaska Zone 2       26932
# 119       120  AK_5  Alaska Zone 5       26935
# 120       121  AK_8  Alaska Zone 8       26938
#
#                                               geometry
# 0    MULTIPOLYGON (((-155.66619 18.92178, -155.5377...
# 1    MULTIPOLYGON (((-156.19605 20.63165, -156.1318...
# 2    MULTIPOLYGON (((-157.67333 21.29802, -157.7134...
# 3    MULTIPOLYGON (((-159.33518 21.94835, -159.3271...
# 4    MULTIPOLYGON (((-160.07380 22.00418, -160.1219...
# ..                                                 ...
# 116  MULTIPOLYGON (((-150.97180 61.19444, -150.9527...
# 117  MULTIPOLYGON (((-144.00179 64.68149, -144.0018...
# 118  MULTIPOLYGON (((-140.99891 61.89455, -141.0024...
# 119  MULTIPOLYGON (((-152.01540 60.68988, -152.0153...
# 120  MULTIPOLYGON (((-164.39951 66.58865, -164.7202...
#
# [121 rows x 5 columns]

# %%
ceshi2.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_65b1370f2a5ca1d2617425841814ec4e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_65b1370f2a5ca1d2617425841814ec4e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_65b1370f2a5ca1d2617425841814ec4e = L.map(
#                 &quot;map_65b1370f2a5ca1d2617425841814ec4e&quot;,
#                 {
#                     center: [45.1640088181819, -122.5934375],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_65b1370f2a5ca1d2617425841814ec4e);
#
#
#
#
#
#             var tile_layer_8abc0ec181f0a1b45961a2bc9736840d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8abc0ec181f0a1b45961a2bc9736840d.addTo(map_65b1370f2a5ca1d2617425841814ec4e);
#
#
#             map_65b1370f2a5ca1d2617425841814ec4e.fitBounds(
#                 [[18.9217818181819, -178.2176], [71.4062358181819, -66.969275]],
#                 {}
#             );
#
#
#         function geo_json_3262e6c861864d580451e85e20fdfeb1_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_3262e6c861864d580451e85e20fdfeb1_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_3262e6c861864d580451e85e20fdfeb1_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_3262e6c861864d580451e85e20fdfeb1_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_3262e6c861864d580451e85e20fdfeb1_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_3262e6c861864d580451e85e20fdfeb1.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_3262e6c861864d580451e85e20fdfeb1_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_3262e6c861864d580451e85e20fdfeb1 = L.geoJson(null, {
#                 onEachFeature: geo_json_3262e6c861864d580451e85e20fdfeb1_onEachFeature,
#
#                 style: geo_json_3262e6c861864d580451e85e20fdfeb1_styler,
#                 pointToLayer: geo_json_3262e6c861864d580451e85e20fdfeb1_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_3262e6c861864d580451e85e20fdfeb1_add (data) {
#             geo_json_3262e6c861864d580451e85e20fdfeb1
#                 .addData(data);
#         }
#             geo_json_3262e6c861864d580451e85e20fdfeb1_add({&quot;bbox&quot;: [-178.2176, 18.9217818181819, -66.969275, 71.4062358181819], &quot;features&quot;: [{&quot;bbox&quot;: [-156.043526, 18.9217818181819, -154.791104, 20.2704858181818], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-155.666192, 18.9217818181819], [-155.537726, 19.042210818182], [-155.521679, 19.1224818181818], [-155.304896, 19.2348828181818], [-155.152373, 19.2669948181818], [-155.015879, 19.3312098181819], [-154.92758, 19.4195178181819], [-154.815188, 19.4596758181819], [-154.791104, 19.5399648181818], [-154.975766, 19.6523388181819], [-154.975766, 19.7406468181819], [-155.072111, 19.7245818181819], [-155.096186, 19.877113818182], [-155.200559, 19.9975248181819], [-155.561828, 20.1340098181819], [-1

# %%
ceshi3 = ceshi.sjoin(ceshi2, how='left', predicate='intersects')
ceshi3
# Out:
#              dist_name dist_abbr  planned_dev  overlay  \
# 0          Residential         R        False    False
# 1        Single-Family       R-S        False    False
# 2      Multiple-Family       R-M        False    False
# 3           Commercial         C        False    False
# 4           Commercial       C-A        False    False
# 5  Planned Development        PD         True    False
#
#                                    res_types_allowed  \
# 0                                                NaN
# 1                        [single_family, two_family]
# 2  [single_family, two_family, multiple_family, t...
# 3  [single_family, two_family, multiple_family, t...
# 4                                                NaN
# 5                                                NaN
#
#                                          constraints  \
# 0                                                NaN
# 1  {'lot_area': {'min_val': [{'expression': '0.16...
# 2  {'lot_area': {'min_val': [{'expression': '0.16...
# 3  {'lot_area': {'min_val': [{'expression': '0.16...
# 4                                                NaN
# 5                                                NaN
#
#                                             geometry  index_right  OBJECTID  \
# 0                                               None          NaN       NaN
# 1  MULTIPOLYGON (((-96.87971 32.73877, -96.87970 ...         56.0      57.0
# 2  MULTIPOLYGON (((-96.88145 32.73920, -96.88165 ...         56.0      57.0
# 3  MULTIPOLYGON (((-96.87860 32.73980, -96.87859 ...         56.0      57.0
# 4  MULTIPOLYGON (((-96.87949 32.73959, -96.87950 ...         56.0      57.0
# 5                                               None          NaN       NaN
#
#     ZONE             ZONENAME  EPSG_NAD83
# 0    NaN                  NaN         NaN
# 1  TX_NC  Texas North Central     32138.0
# 2  TX_NC  Texas North Central     32138.0
# 3  TX_NC  Texas North Central     32138.0
# 4  TX_NC  Texas North Central     32138.0
# 5    NaN                  NaN         NaN

# %%
zp_run_zoning_checks(r"/Users/houpuli/Redlining Lab Dropbox/HOUPU LI/ceshi/tidybuilding/2_fam.bldg", 
                     r'/Users/houpuli/Redlining Lab Dropbox/HOUPU LI/ceshi/test',
                     r'/Users/houpuli/Redlining Lab Dropbox/HOUPU LI/ceshi/test',
                     detailed_check=True,
                     checks=possible_checks,
                     )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 zp_run_zoning_checks(r"/Users/houpuli/Redlining Lab Dropbox/HOUPU LI/ceshi/tidybuilding/2_fam.bldg",
#       2                      r'/Users/houpuli/Redlining Lab Dropbox/HOUPU LI/ceshi/test',
#       3                      r'/Users/houpuli/Redlining Lab Dropbox/HOUPU LI/ceshi/test',
#       4                      detailed_check=True,
#       5                      checks=possible_checks,
#       6                      )
#
# File /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/zonepy/zp_run_zoning_checks.py:104, in zp_run_zoning_checks(bldg_file, parcel_files, zoning_files, detailed_check, print_checkpoints, checks, save_to)
#     102 target_crs = None
#     103 for muni_id, zf in enumerate(zoning_files):
# --> 104     gz = zp_read_dist(zf)
#     105     if first:
#     106         target_crs = gz.crs
#
# File /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/zonepy/zp_read_dist.py:37, in zp_read_dist(path, trans_crs, index_col)
#      35     target_crs = trans_crs
#      36 else:
# ---> 37     auto_epsg = zp_get_crs(path, large_area=False)
#      38     target_crs = f"EPSG:{auto_epsg}"
#      40 # 3. Reproject to the target CRS
#
# File /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/zonepy/zp_get_crs.py:69, in zp_get_crs(geom_data, large_area)
#      66 joined = gpd.sjoin(geom, state_planes_crs, how="inner", predicate="intersects")
#      68 if joined.empty:
# ---> 69     raise ValueError(
#      70         "No intersection found with any State Plane zone."
#      71     )
#      73 # Count how many times each state plane index appears
#      74 counts = joined["index_right"].value_counts()
#
# ValueError: No intersection found with any State Plane zone.

# %% [markdown]
# # Forget the following lines, this is just some process test for debug coding.

# %%
import time
import warnings
from joblib import Parallel, delayed
from tqdm import tqdm

import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from shapely.geometry import Point
from shapely.geometry import box
from shapely.geometry import mapping
import os
import json
import glob

# input my libraries
from zonepy import zp_get_crs
from zonepy import zp_find_district_idx
from zonepy import zp_read_dist
from zonepy import zp_read_pcl
from zonepy import zp_read_bldg
from zonepy import zp_get_dist_def
from zonepy import zp_get_parcel_dim
from zonepy import zp_get_parcel_geo
from zonepy import zp_get_unit_info
from zonepy import zp_get_variables
from zonepy import zp_get_zoning_req
from zonepy import zp_check_unit
from zonepy import zp_check_res_type
from zonepy import zp_check_constraints
from zonepy import zp_add_setbacks
from zonepy import zp_get_buildable_area
from zonepy import zp_check_fit
from zonepy import possible_checks

start_time = time.time()

# ————————— 0. 参数检查 ————————— #
# 1. 检查 checks 入参
checks = possible_checks.copy()
bad = [c for c in checks if c not in possible_checks]
if bad:
    warnings.warn(f"Unknown constraints: {bad}")

# 2. 取初始要跑的约束（不含内建的 res_type/unit_size/bldg_fit/overlay）
initial_checks = [
    c for c in checks
    if c not in ("res_type", "unit_size", "bldg_fit", "overlay")
]

zoning_files = r"/Users/houpuli/Redlining Lab Dropbox/HOUPU LI/ceshi/ceshi_7_27"
parcel_files = r"/Users/houpuli/Redlining Lab Dropbox/HOUPU LI/ceshi/ceshi_7_27"
bldg_file = r"/Users/houpuli/Redlining Lab Dropbox/HOUPU LI/ceshi/tidybuilding/4_fam_wide.bldg"

# 3. 处理 zoning_files：支持单路径或文件夹
if isinstance(zoning_files, str):
    if os.path.isdir(zoning_files):
        zoning_files = glob.glob(os.path.join(zoning_files, "*.zoning"))
    else:
        zoning_files = [zoning_files]

# 4. 处理 parcel_files：同上
if isinstance(parcel_files, str):
    if os.path.isdir(parcel_files):
        parcel_files = glob.glob(os.path.join(parcel_files, "*.parcel"))
    else:
        parcel_files = [parcel_files]

# ————————— 1、数据准备 ————————— #
# 1. 读建筑 JSON
bldg_data = zp_read_bldg(bldg_file)


# 2. 读 zoning 图层 + JSON
zoning_gdfs = []
zoning_jsons = []

first = True
target_crs = None
for muni_id, zf in enumerate(zoning_files):
    gz = zp_read_dist(zf)
    if first:
        target_crs = gz.crs
        first = False
    else:
        gz = gz.to_crs(target_crs)
    with open(zf, "r") as f:
        js = json.load(f)
    gz["muni_name"] = js.get("muni_name")  
    gz["muni_id"] = muni_id
    zoning_gdfs.append(gz)
    zoning_jsons.append(js)
    
zoning_all = pd.concat(zoning_gdfs, ignore_index=True)
zoning_all['zoning_id'] = (zoning_all['muni_id'].astype(int).astype(str) + '_' + zoning_all['zoning_id'].astype(int).astype(str))

# 4. 拆出 overlay / planned_dev / base three sets
overlays = zoning_all[zoning_all["overlay"]   == True]
pd_districts = zoning_all[zoning_all["planned_dev"]== True]
base_zones  = zoning_all[(zoning_all["overlay"]   == False) & (zoning_all["planned_dev"]== False)]

# 5. 读 Parcels 并且赋予 base_id
parcel_list = [ zp_read_pcl(p, base_zones) for p in parcel_files ]
parcels_sf = pd.concat(parcel_list, ignore_index=True)

parcel_geo  = zp_get_parcel_geo(parcels_sf)
parcel_dims  = zp_get_parcel_dim(parcels_sf)

parcel_dims = parcel_dims.rename(columns={"zoning_id":"muni_base_id"})

# 8. 给 parcel_dims 打 pd_id、overlay_id，
pd_idx = zp_find_district_idx(parcel_dims, pd_districts).rename(columns={"zoning_id":"muni_pd_id"})
ov_idx = zp_find_district_idx(parcel_dims, overlays).rename(columns={"zoning_id":"muni_overlay_id"})
parcel_dims = parcel_dims.merge(pd_idx[["parcel_id","muni_pd_id"]], on='parcel_id', how="left")
parcel_dims = parcel_dims.merge(ov_idx[["parcel_id","muni_overlay_id"]], on='parcel_id', how="left")

# 9. 添 muni_name & dist_abbr
dist_abbr_map = zoning_all.set_index("zoning_id")["dist_abbr"].to_dict()
muni_name_map = zoning_all.set_index("zoning_id")["muni_name"].to_dict()

def collect_all(ids, mapping):
    """给一个 list of zoning_id，去 mapping 里拿值并去重。"""
    vals = []
    for z_id in ids:
        if pd.notna(z_id):
            v = mapping.get(z_id)
            # zoning_json 里有些可能是 list，我们也要展开
            if isinstance(v, (list, tuple)):
                vals.extend(v)
            elif v is not None:
                vals.append(v)
    # 去重并保持顺序
    seen = set()
    uniq = []
    for v in vals:
        if v not in seen:
            seen.add(v)
            uniq.append(v)
    return uniq

# 先把三个 id 列合成 list
parcel_dims["all_zone_ids"] = parcel_dims[[
    "muni_base_id","muni_pd_id","muni_overlay_id"
]].values.tolist()

# 然后生成两个新列
parcel_dims["dist_abbr"] = parcel_dims["all_zone_ids"].apply(
    lambda ids: collect_all(ids, dist_abbr_map)
)
parcel_dims["muni_name"] = parcel_dims["all_zone_ids"].apply(
    lambda ids: collect_all(ids, muni_name_map)
)

# 10. 初始化 false/maybe 原因列
parcel_dims["false_reasons"] = None
parcel_dims["maybe_reasons"] = None
false_dfs = []
maybe_dfs = []
detailed_check = True

# ————————— 2、PD 检查 ————————— #
t0 = time.time()
if not pd_districts.empty:
    # 哪些 parcel 在 PD 区里？ 通过 muni_pd_id 来判断
    pd_parcels = pd_idx["parcel_id"][pd_idx["muni_pd_id"].notna()]
    # 标记这些 parcel 为 FALSE 并记录原因
    mask_pd = parcel_dims["parcel_id"].isin(pd_parcels)
    parcel_dims.loc[mask_pd, "false_reasons"] = (
        parcel_dims.loc[mask_pd, "false_reasons"]
        .fillna("") .apply(lambda s: "PD_dist" if s=="" else s+",PD_dist")
    )
    # 添一个中间变量 check_pd，用于后面 detailed_check 逻辑
    parcel_dims["check_pd"] = ~mask_pd
    if not detailed_check:
        df0 = parcel_dims[ mask_pd ]
        false_dfs.append(df0)
        parcel_dims = parcel_dims[~mask_pd]

# ————————— 3、District 检查 ————————— #
t1 = time.time()
# 1. 警告跨区的 parcels
# 找出那些 muni_base_id 是 list 且长度 >1 的行
mask_dist_cross = parcel_dims["muni_base_id"].apply(lambda x: isinstance(x, (list, tuple)) and len(x) > 1)
crossing = parcel_dims.loc[mask_dist_cross, "parcel_id"]
if not crossing.empty:
    # 在 maybe_reasons 里拼接 cross_base_district
    parcel_dims.loc[mask_dist_cross, "maybe_reasons"] = (
        parcel_dims.loc[mask_dist_cross, "maybe_reasons"]
        .fillna("")  # None -> ""
        .apply(lambda s: "cross_base_district" if s == "" else s + ",cross_base_district")
    )
    warnings.warn(f"{len(crossing)}/{len(parcel_dims)} parcels acrossed by zoning")
    # 记录一个中间标记，用于 detailed_check 逻辑
    parcel_dims["check_cross_base"] = ~mask_dist_cross
# 2. 警告不在任何区的 parcels
mask_dist_cover = (parcel_dims["muni_base_id"].isna() & parcel_dims["muni_pd_id"].isna() & parcel_dims["muni_overlay_id"].isna())
missing = parcel_dims.loc[mask_dist_cover, "parcel_id"]
if not missing.empty:
    # 在 maybe_reasons 里拼接 no_district
    parcel_dims.loc[mask_dist_cover, "maybe_reasons"] = (
        parcel_dims.loc[mask_dist_cover, "maybe_reasons"]
        .fillna("")  # None -> ""
        .apply(lambda s: "no_district" if s == "" else s + ",no_district")
    )
    warnings.warn(f"{len(missing)}/{len(parcel_dims)} parcels not covered by zoning")
    # 添一个中间变量 check_pd，用于后面 detailed_check 逻辑
    parcel_dims["check_dist_cover"] = ~mask_dist_cover

# 单独处理 cross_base
df_cross = parcel_dims.loc[mask_dist_cross].copy()
# 先拼出一个同时包含 cross_base 和 no_district 的联合掩码
mask_dist = mask_dist_cross | mask_dist_cover
# 把这批 rows 保存到一个新的 DataFrame
df_dist = parcel_dims.loc[mask_dist]
maybe_dfs.append(df_dist)
# 然后把它们从主表里删除
parcel_dims = parcel_dims.loc[~mask_dist]

# ————————— 4、变量 & 要求 ————————— #
# —— 逐 parcel 执行 get_variables / get_zoning_req —— #
t2 = time.time()
vars_map = {}
req_map  = {}
no_setback = set()
for idx in parcel_dims.index:
    # 这里用双中括号把它取成 DataFrame 而不是 Series
    parcel_data = parcel_dims.loc[[idx]]   
    pid = parcel_data.at[idx, "parcel_id"]
    # 找到对应 district 的 DataFrame 子集
    ids = (parcel_data.at[idx, "muni_base_id"]
        if isinstance(parcel_data.at[idx, "muni_base_id"], (list, tuple))
        else [parcel_data.at[idx, "muni_base_id"]])
    dist_df = zoning_all[zoning_all["zoning_id"].isin(ids)]
    # 如果没区划，直接跳过
    if dist_df.empty:
        continue
    # munijson 也要从 dist_df 里取 .iloc[0]
    muni = int(dist_df.iloc[0]["muni_id"])
    munijson = zoning_jsons[muni]["definitions"]
    # 现在给 zp_get_variables 传入正确类型
    v = zp_get_variables(bldg_data, parcel_data, dist_df, munijson)
    z = zp_get_zoning_req(dist_df, bldg_data=None, parcel_data=None, zoning_data=None, vars=v)
    vars_map[pid] = v
    req_map[pid]  = z
    # 记录 no_setback
    if isinstance(z, str):
        no_setback.add(pid)
    else:
        sb = z[z["constraint_name"].str.contains("setback")]["min_value"]
        if sb.isnull().all() or sb.apply(lambda x: sum(x if isinstance(x,(list,tuple)) else [x])).sum()==0:
            no_setback.add(pid)
            
# ————————— 5、初检 (res_type + constraints + unit_size) ————————— #
t2 = time.time()
init_results = {}
for idx in parcel_dims.index:
    # 1) 取出单行 DataFrame
    parcel_data = parcel_dims.loc[[idx]]
    pid = parcel_data.at[idx, "parcel_id"]
    # 2) 取出要用的 drow（也是 DataFrame）
    ids = (parcel_data.at[idx, "muni_base_id"]
        if isinstance(parcel_data.at[idx, "muni_base_id"], (list, tuple))
        else [parcel_data.at[idx, "muni_base_id"]])
    dist_df = zoning_all[zoning_all["zoning_id"].isin(ids)]
    # 如果没区划，直接跳过
    if dist_df.empty:
        continue
    # 3) 拿到变量 v 和要求 z
    v   = vars_map[pid]
    z   = req_map[pid]

    # 1) 用地类型
    if "res_type" in checks:
        rt_ok = zp_check_res_type(v, dist_df)
        df_rt = pd.DataFrame({"res_type":[rt_ok]})
    else:
        df_rt = pd.DataFrame()

    # 2) 其他定量约束
    try:
        df_cons = zp_check_constraints(v, z, checks=initial_checks)
    except:
        df_cons = pd.DataFrame()
    if not df_cons.empty:
        df_c = df_cons.set_index("constraint_name")["allowed"].to_frame().T
    else:
        df_c = pd.DataFrame()

    # 3) 户型尺寸
    if "unit_size" in checks:
        u_ok = zp_check_unit(dist_df, bldg_data, v)
        df_u = pd.DataFrame({"unit_size":[u_ok]})
    else:
        df_u = pd.DataFrame()

    # 合并
    merged = pd.concat([df_rt, df_c.reset_index(drop=True), df_u], axis=1)
    merged.index = [idx]
    init_results[idx] = merged

    # 记录 FALSE/MAYBE 原因
    vals = merged.iloc[0].astype(str)
    fals = vals[vals=="False"].index.tolist()
    mays = vals[vals=="MAYBE"].index.tolist()
    if fals:
        s = parcel_dims.at[idx,"false_reasons"] or ""
        parcel_dims.at[idx,"false_reasons"] = (",".join(fals) if s=="" else s + "," + ",".join(fals))
    if mays:
        s = parcel_dims.at[idx,"maybe_reasons"] or ""
        parcel_dims.at[idx,"maybe_reasons"] = (",".join(mays)if s=="" else s + "," + ",".join(mays))

    # 如果有 FALSE，就剔除
    if ("False" in vals.values) and (not detailed_check):
        false_dfs.append(parcel_dims.loc[[idx]])
        parcel_dims.drop(idx, inplace=True)

# 把所有拆成一张大表，保留原始 idx 作为索引
init_df = pd.concat(init_results, axis=0)
# 这时 init_df 有一个两级索引，第一层就是原始的 idx, 把第一层索引删掉，只保留行号
init_df.index = init_df.index.droplevel(0)
# NA 当 TRUE
init_df = init_df.fillna(True)
# 然后直接和 parcel_dims 对齐 join
parcel_dims = parcel_dims.join(init_df)

# ————————— 5、侧面标签检查 ————————— #
if "bldg_fit" in checks and not parcel_dims.empty:
    t3 = time.time()
    known = set(parcel_geo.loc[parcel_geo["side"]!="unknown","parcel_id"])
    keep = known.union(no_setback)
    # 标记 parcel_side_lbl
    parcel_dims["parcel_side_lbl"] = parcel_dims["parcel_id"].isin(keep)
    # 没标签的设为 MAYBE
    mask = ~parcel_dims["parcel_side_lbl"]
    parcel_dims.loc[mask, "maybe_reasons"] = (
        parcel_dims.loc[mask, "maybe_reasons"]
        .fillna("") .apply(lambda s: "side_lbl" if s=="" else s+",side_lbl")
    )
    # 非 detailed → 剔除
    if not detailed_check:
        false_dfs.append(parcel_dims[mask])
        parcel_dims = parcel_dims[~mask]
        
        
parcel_dims["bldg_fit"] = None
parcel_dims["bldg_fit"] = parcel_dims["bldg_fit"].astype(object)

# ————————— 6、建面 Fit 检查 ————————— #
if "bldg_fit" in checks and not parcel_dims.empty:
    t4 = time.time()
    for idx in parcel_dims.index:
        # 如果 side label 不符合，就跳过
        if not parcel_dims.at[idx, "parcel_side_lbl"]:
            continue
        # 1) 取出单行 DataFrame
        pid = parcel_dims.at[idx, "parcel_id"]
        sides = parcel_geo[parcel_geo["parcel_id"] == pid]
        if sides.empty:
            continue
        # 2) 取出要用的 drow（也是 DataFrame）
        base_ids = parcel_dims.at[idx, "muni_base_id"]
        if not isinstance(base_ids, (list, tuple)):
            base_ids = [base_ids]
        dist_df = zoning_all[zoning_all["zoning_id"].isin(base_ids)]
        # 如果没区划，直接跳过
        if dist_df.empty:
            continue
        # 3) 拿到变量 v 和要求 z
        v   = vars_map[pid]
        z   = req_map[pid]
        pg_sb = zp_add_setbacks(sides, dist_df, z)
        bz    = zp_get_buildable_area(pg_sb)
        fitdf = zp_check_fit(bz, v)
        ok = fitdf.loc[0,"allowed"]
        parcel_dims.at[idx,"bldg_fit"] = ok
        if ok=="MAYBE":
            s = parcel_dims.at[idx,"maybe_reasons"] or ""
            parcel_dims.at[idx,"maybe_reasons"] = "bldg_fit" if s=="" else s+",bldg_fit"
        if ok==False:
            s = parcel_dims.at[idx,"false_reasons"] or ""
            parcel_dims.at[idx,"false_reasons"] = "bldg_fit" if s=="" else s+",bldg_fit"
    if not detailed_check:
        mask = parcel_dims["bldg_fit"]==False
        false_dfs.append(parcel_dims[mask])
        parcel_dims = parcel_dims[~mask]

# ————————— 7、Overlay 检查 ————————— #
if "overlay" in checks and not overlays.empty:
    t6 = time.time()
    o_parcels = set(overlays["parcel_id"])
    mask = parcel_dims["parcel_id"].isin(o_parcels)
    parcel_dims.loc[mask, "maybe_reasons"] = (
        parcel_dims.loc[mask, "maybe_reasons"]
        .fillna("") .apply(lambda s: "overlay" if s=="" else s+",overlay")
    )
    if print_checkpoints:
        print(f"___overlay_check___ {time.time()-t6:.1f}s\n")

# ————————— 8、合并 & 输出 ————————— #
# 拼回所有被剔除的 false_dfs
final = pd.concat(false_dfs + [parcel_dims], ignore_index=True)

# 计算 allowed & reason
def summarize(r):
    fr = r.get("false_reasons") or ""
    mr = r.get("maybe_reasons") or ""
    if fr: return (False, fr)
    if mr: return ("MAYBE", mr)
    return (True, "Building allowed")

final[["allowed","reason"]] = pd.DataFrame(
    final.apply(summarize, axis=1).tolist(),
    index=final.index
)

# %% [markdown]
# ## Create Different Functions

# %% [markdown]
# ### `find_bldg_type` function

# %%
# find_bldg_type_results = find_bldg_type(tidybuilding_4_fam_wide)
# find_bldg_type_results
# Out:
# '4_plus'

# %% [markdown]
# <!-- ### `get_zoning_req` function
# - `find_bldg_type` functiona is integrated internally. -->

# %%
# zoning_id = find_district_idx(Dallas_parcels, Dallas_district)
# zoning_id[zoning_id['zoning_id'] == 12]
# Out:
#                                     parcel_id  zoning_id
# 13260    Collin_County_combined_parcel_157917         12
# 17484    Collin_County_combined_parcel_176197         12
# 29920    Collin_County_combined_parcel_227817         12
# 32766    Collin_County_combined_parcel_239997         12
# 37033    Collin_County_combined_parcel_259100         12
# ...                                       ...        ...
# 1560787  Dallas_County_combined_parcel_673595         12
# 1571277  Dallas_County_combined_parcel_676445         12
# 1588645  Dallas_County_combined_parcel_685906         12
# 1590583  Dallas_County_combined_parcel_690594         12
# 1594376  Dallas_County_combined_parcel_691855         12
#
# [151 rows x 2 columns]

# %%
# get_zoning_req_results = get_zoning_req(district_data, bldg_data=None, parcel_data=None, zoning_data=None, vars=get_variables_results)
# get_zoning_req_results
# Out:
#     constraint_name  min_value  max_value min_val_error max_val_error
# 0     setback_front       20.0        NaN          None          None
# 1  setback_side_int        6.0        NaN          None          None
# 2  setback_side_ext       20.0        NaN          None          None
# 3      setback_rear       10.0        NaN          None          None
# 4      lot_cov_bldg        NaN       55.0          None          None
# 5            height        NaN       40.0          None          None
# 6         unit_size      900.0        NaN          None          None
# 7      unit_density        NaN        5.5          None          None

# %% [markdown]
# <!-- ### `Check` function -->

# %% [markdown]
# <!-- #### 01. `check_land_use` function
# - `find_bldg_type` function is integrated internally. -->

# %%
# check_land_use_results = check_land_use(tidybuilding_4_fam_wide, Dallas_district)
# check_land_use_results
# Out:
#     zoning_id  allowed
# 0           0    False
# 1           1    False
# 2           2    False
# 3           3    False
# 4           4    False
# 5           5    False
# 6           6    False
# 7           7    False
# 8           8    False
# 9           9    False
# 10         10    False
# 11         11    False
# 12         12     True
# 13         13     True
# 14         14     True
# 15         15     True
# 16         16     True
# 17         17    False
# 18         18    False
# 19         19    False
# 20         20    False
# 21         21    False
# 22         22    False
# 23         23    False
# 24         24    False
# 25         25    False
# 26         26    False
# 27         27    False
# 28         28    False
# 29         29    False
# 30         30    False
# 31         31    False
# 32         32    False
# 33         33    False
# 34         34    False
# 35         35    False
# 36         36    False
# 37         37    False
# 38         38    False
# 39         52     True
# 40         53     True
# 41         54     True
# 42         55     True
# 43         56     True
# 44         57     True
# 45         59     True
# 46         60     True
# 47         61     True
# 48         62     True
# 49         63     True
# 50         64     True
# 51         65     True
# 52         66     True
# 53         67     True
# 54         68     True
# 55         70     True

# %% [markdown]
# <!-- #### 02. `check_fl_area` function
# - `get_zoning_req` function is integrated internally. -->

# %%
# check_fl_area(tidybuilding_4_fam_wide, Dallas_district[Dallas_district['zoning_id'] == 12], Dallas_parcels[Dallas_parcels['parcel_id'] == 'Collin_County_combined_parcel_157917'])
# Out:
#    zoning_id  allowed constraint_min_note constraint_max_note
# 0         12     True                None                None

# %%
# check_fl_area_result_all = check_zoning_process(tidybuilding_4_fam_wide, Dallas_district, Dallas_parcels, check_fl_area, n_jobs=12)
# check_fl_area_result_all
# Out:
# Parallel Processing:   2%|▏         | 156/9859 [00:23<26:45,  6.04it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:   2%|▏         | 192/9859 [00:29<27:12,  5.92it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:   2%|▏         | 204/9859 [00:32<29:52,  5.39it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:   2%|▏         | 240/9859 [00:38<27:57,  5.73it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:   3%|▎         | 276/9859 [00:44<27:39,  5.77it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:   3%|▎         | 324/9859 [00:53<27:35,  5.76it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:   3%|▎         | 336/9859 [00:56<30:29,  5.21it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:   4%|▎         | 348/9859 [00:57<28:01,  5.66it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:   4%|▍         | 372/9859 [01:02<29:12,  5.41it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:   4%|▍         | 384/9859 [01:04<28:35,  5.52it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:   4%|▍         | 408/9859 [01:08<28:45,  5.48it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:   4%|▍         | 420/9859 [01:11<31:14,  5.03it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:   5%|▍         | 468/9859 [01:20<27:41,  5.65it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:   6%|▌         | 552/9859 [01:34<26:15,  5.91it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:   6%|▌         | 588/9859 [01:40<26:33,  5.82it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:   6%|▌         | 600/9859 [01:43<28:26,  5.42it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:   6%|▌         | 612/9859 [01:45<28:48,  5.35it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:   6%|▋         | 624/9859 [01:47<28:10,  5.46it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:   6%|▋         | 636/9859 [01:49<28:03,  5.48it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:   7%|▋         | 672/9859 [01:56<27:04,  5.66it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:   8%|▊         | 744/9859 [02:08<25:31,  5.95it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:   8%|▊         | 757/9859 [02:11<27:02,  5.61it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:   8%|▊         | 768/9859 [02:13<28:50,  5.25it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:   8%|▊         | 780/9859 [02:15<28:12,  5.36it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:   9%|▊         | 852/9859 [02:28<25:21,  5.92it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:   9%|▉         | 864/9859 [02:30<26:03,  5.75it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:   9%|▉         | 877/9859 [02:33<29:45,  5.03it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:   9%|▉         | 924/9859 [02:41<25:00,  5.95it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  10%|▉         | 948/9859 [02:45<25:51,  5.74it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  10%|▉         | 984/9859 [02:51<24:51,  5.95it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  10%|█         | 1008/9859 [02:55<25:14,  5.85it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  11%|█         | 1044/9859 [03:02<25:41,  5.72it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  11%|█         | 1056/9859 [03:04<27:39,  5.31it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  11%|█         | 1068/9859 [03:06<26:47,  5.47it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  11%|█         | 1092/9859 [03:11<25:57,  5.63it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  11%|█         | 1104/9859 [03:13<26:10,  5.58it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  12%|█▏        | 1140/9859 [03:20<25:46,  5.64it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  12%|█▏        | 1176/9859 [03:26<24:36,  5.88it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  12%|█▏        | 1224/9859 [03:34<23:57,  6.01it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  13%|█▎        | 1236/9859 [03:37<26:45,  5.37it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  13%|█▎        | 1248/9859 [03:39<26:07,  5.49it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  13%|█▎        | 1272/9859 [03:43<24:49,  5.77it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  13%|█▎        | 1296/9859 [03:47<24:54,  5.73it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  14%|█▍        | 1356/9859 [03:57<23:37,  6.00it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  14%|█▍        | 1392/9859 [04:03<23:54,  5.90it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  14%|█▍        | 1404/9859 [04:06<24:25,  5.77it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  14%|█▍        | 1428/9859 [04:10<25:05,  5.60it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  15%|█▍        | 1440/9859 [04:12<24:51,  5.64it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  15%|█▍        | 1476/9859 [04:18<23:53,  5.85it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  15%|█▌        | 1500/9859 [04:23<25:15,  5.51it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  15%|█▌        | 1512/9859 [04:25<24:44,  5.62it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  16%|█▌        | 1560/9859 [04:34<23:35,  5.86it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  16%|█▋        | 1608/9859 [04:42<23:02,  5.97it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  17%|█▋        | 1632/9859 [04:46<23:44,  5.77it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  17%|█▋        | 1644/9859 [04:48<23:54,  5.73it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  17%|█▋        | 1656/9859 [04:51<25:42,  5.32it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  17%|█▋        | 1668/9859 [04:53<25:34,  5.34it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  18%|█▊        | 1740/9859 [05:05<22:26,  6.03it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  18%|█▊        | 1764/9859 [05:10<24:22,  5.53it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  18%|█▊        | 1812/9859 [05:18<22:41,  5.91it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  19%|█▊        | 1824/9859 [05:20<25:37,  5.22it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  19%|█▉        | 1872/9859 [05:29<22:45,  5.85it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  19%|█▉        | 1884/9859 [05:31<23:42,  5.61it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  19%|█▉        | 1896/9859 [05:33<23:21,  5.68it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  19%|█▉        | 1920/9859 [05:37<23:38,  5.60it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  20%|█▉        | 1932/9859 [05:39<23:31,  5.62it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  20%|█▉        | 1944/9859 [05:42<23:44,  5.56it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  20%|██        | 1980/9859 [05:48<22:31,  5.83it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  20%|██        | 2004/9859 [05:52<23:13,  5.64it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  20%|██        | 2016/9859 [05:54<23:40,  5.52it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  21%|██        | 2040/9859 [05:58<22:28,  5.80it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  21%|██        | 2052/9859 [06:01<22:51,  5.69it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  21%|██▏       | 2100/9859 [06:09<21:48,  5.93it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  22%|██▏       | 2124/9859 [06:13<22:37,  5.70it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  22%|██▏       | 2136/9859 [06:16<24:47,  5.19it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  22%|██▏       | 2160/9859 [06:20<23:07,  5.55it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  22%|██▏       | 2208/9859 [06:28<21:37,  5.90it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  23%|██▎       | 2256/9859 [06:36<21:14,  5.97it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  23%|██▎       | 2268/9859 [06:39<21:42,  5.83it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  23%|██▎       | 2292/9859 [06:43<22:24,  5.63it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  24%|██▎       | 2328/9859 [06:49<21:34,  5.82it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  24%|██▎       | 2340/9859 [06:52<22:35,  5.55it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  24%|██▍       | 2352/9859 [06:54<22:14,  5.63it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  24%|██▍       | 2364/9859 [06:56<22:59,  5.43it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  24%|██▍       | 2376/9859 [06:58<23:01,  5.41it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  24%|██▍       | 2388/9859 [07:01<23:58,  5.19it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  25%|██▍       | 2436/9859 [07:09<21:13,  5.83it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  25%|██▍       | 2460/9859 [07:13<21:51,  5.64it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  25%|██▌       | 2496/9859 [07:19<20:51,  5.88it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  26%|██▌       | 2520/9859 [07:24<21:15,  5.75it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  26%|██▌       | 2544/9859 [07:28<21:21,  5.71it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  26%|██▌       | 2568/9859 [07:32<21:42,  5.60it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  26%|██▋       | 2592/9859 [07:37<21:08,  5.73it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  27%|██▋       | 2652/9859 [07:47<20:01,  6.00it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  27%|██▋       | 2664/9859 [07:49<21:17,  5.63it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  27%|██▋       | 2688/9859 [07:53<20:50,  5.74it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  27%|██▋       | 2700/9859 [07:56<21:10,  5.64it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  28%|██▊       | 2712/9859 [07:58<22:19,  5.34it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  28%|██▊       | 2724/9859 [08:01<23:22,  5.09it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  28%|██▊       | 2736/9859 [08:03<23:12,  5.11it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  28%|██▊       | 2760/9859 [08:07<21:07,  5.60it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  28%|██▊       | 2772/9859 [08:09<21:09,  5.58it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  29%|██▉       | 2856/9859 [08:23<19:21,  6.03it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  29%|██▉       | 2892/9859 [08:29<19:29,  5.96it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  29%|██▉       | 2904/9859 [08:32<20:58,  5.52it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  30%|██▉       | 2928/9859 [08:36<20:45,  5.56it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  30%|███       | 2964/9859 [08:43<20:32,  5.60it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  30%|███       | 2977/9859 [08:45<20:10,  5.68it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  31%|███       | 3024/9859 [08:53<19:06,  5.96it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  31%|███       | 3036/9859 [08:55<19:44,  5.76it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  31%|███       | 3048/9859 [08:57<20:15,  5.60it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  31%|███       | 3072/9859 [09:02<19:52,  5.69it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  31%|███▏      | 3084/9859 [09:04<20:02,  5.64it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  32%|███▏      | 3120/9859 [09:10<19:20,  5.80it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  32%|███▏      | 3144/9859 [09:14<19:15,  5.81it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# ...
#   warnings.warn(
# Parallel Processing:  89%|████████▊ | 8748/9859 [26:23<03:12,  5.78it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  89%|████████▉ | 8760/9859 [26:26<03:13,  5.68it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  89%|████████▉ | 8796/9859 [26:32<03:03,  5.78it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  90%|████████▉ | 8832/9859 [26:38<02:58,  5.77it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  90%|█████████ | 8892/9859 [26:49<02:47,  5.77it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  91%|█████████ | 8928/9859 [26:56<02:40,  5.80it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  91%|█████████ | 8940/9859 [26:58<02:48,  5.45it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  91%|█████████ | 8976/9859 [27:05<02:34,  5.70it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  92%|█████████▏| 9036/9859 [27:15<02:20,  5.84it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  92%|█████████▏| 9048/9859 [27:17<02:26,  5.55it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  92%|█████████▏| 9096/9859 [27:26<02:11,  5.81it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  93%|█████████▎| 9156/9859 [27:36<02:00,  5.83it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  93%|█████████▎| 9180/9859 [27:41<02:01,  5.60it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  93%|█████████▎| 9216/9859 [27:47<01:52,  5.72it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  94%|█████████▎| 9228/9859 [27:49<01:56,  5.43it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  94%|█████████▎| 9240/9859 [27:52<01:56,  5.32it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  94%|█████████▍| 9312/9859 [28:04<01:32,  5.93it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  95%|█████████▍| 9360/9859 [28:13<01:25,  5.80it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  95%|█████████▌| 9384/9859 [28:17<01:22,  5.76it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  95%|█████████▌| 9408/9859 [28:21<01:17,  5.78it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  96%|█████████▌| 9432/9859 [28:26<01:14,  5.72it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  96%|█████████▌| 9468/9859 [28:32<01:08,  5.73it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  97%|█████████▋| 9528/9859 [28:42<00:56,  5.88it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  97%|█████████▋| 9576/9859 [28:51<00:49,  5.71it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  97%|█████████▋| 9600/9859 [28:55<00:45,  5.65it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  98%|█████████▊| 9624/9859 [29:00<00:43,  5.37it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  98%|█████████▊| 9648/9859 [29:04<00:38,  5.44it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  98%|█████████▊| 9672/9859 [29:09<00:34,  5.39it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  98%|█████████▊| 9708/9859 [29:16<00:27,  5.49it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing:  99%|█████████▉| 9792/9859 [29:30<00:11,  5.90it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing: 100%|█████████▉| 9816/9859 [29:34<00:07,  5.80it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing: 100%|█████████▉| 9840/9859 [29:39<00:03,  5.65it/s]/opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Parallel Processing: 100%|██████████| 9859/9859 [29:41<00:00,  5.53it/s]
# /opt/anaconda3/envs/houpu_py/lib/python3.9/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
#       zoning_id  allowed constraint_min_note constraint_max_note  \
# 0            13     True                None                None
# 1            13     True                None                None
# 2            59     True                None                None
# 3            15     True                None                None
# 4            13     True                None                None
# ...         ...      ...                 ...                 ...
# 9854         13     True                None                None
# 9855         13     True                None                None
# 9856         13     True                None                None
# 9857         13     True                None                None
# 9858         13     True                None                None
#
#                                  parcel_id
# 0     Collin_County_combined_parcel_100650
# 1     Collin_County_combined_parcel_100709
# 2     Collin_County_combined_parcel_100995
# 3     Collin_County_combined_parcel_102352
# 4     Collin_County_combined_parcel_102632
# ...                                    ...
# 9854    Denton_County_combined_parcel_6275
# 9855   Denton_County_combined_parcel_64539
# 9856   Denton_County_combined_parcel_66217
# 9857    Denton_County_combined_parcel_8728
# 9858   Denton_County_combined_parcel_99164
#
# [9859 rows x 5 columns]

# %% [markdown]
# <!-- #### 03. `check_far` function
# - `get_zoning_req` function is integrated internally. -->

# %%
# check_far_result_all = check_zoning_process(tidybuilding_4_fam_wide, Dallas_district, Dallas_parcels, check_far, n_jobs=14)
# check_far_result_all
# Out:
# Parallel Processing: 100%|██████████| 14068/14068 [10:16<00:00, 22.81it/s]
#        zoning_id  allowed constraint_min_note constraint_max_note  \
# 0           1319     True                None                None
# 1           1319     True                None                None
# 2           1761     True                None                None
# 3           1319     True                None                None
# 4           1761     True                None                None
# ...          ...      ...                 ...                 ...
# 14063        168     True                None                None
# 14064        168     True                None                None
# 14065        273     True                None                None
# 14066         71     True                None                None
# 14067        169     True                None                None
#
#                                   parcel_id   Prop_ID
# 0      Collin_County_combined_parcel_100303   1140143
# 1       Collin_County_combined_parcel_10067   2712455
# 2      Collin_County_combined_parcel_100752   2529683
# 3      Collin_County_combined_parcel_101602   1105725
# 4      Collin_County_combined_parcel_102471   2529792
# ...                                     ...       ...
# 14063     Wise_County_combined_parcel_48085  781626.0
# 14064       Wise_County_combined_parcel_647  746915.0
# 14065      Wise_County_combined_parcel_7455  753228.0
# 14066      Wise_County_combined_parcel_8586  790473.0
# 14067      Wise_County_combined_parcel_9195  783634.0
#
# [14068 rows x 6 columns]

# %% [markdown]
# <!-- #### 04. `check_height` function
# - `get_zoning_req` function is integrated internally. -->

# %%
# check_height_result_all = check_zoning_process(tidybuilding_4_fam_wide, tidyzoning, confident_tidyparcel_dim, check_height, n_jobs=-1)
# check_height_result_all
# Out:
# Parallel Processing: 100%|██████████| 14068/14068 [10:10<00:00, 23.04it/s]
#        zoning_id allowed constraint_min_note constraint_max_note  \
# 0           1319    True                None                None
# 1           1319    True                None                None
# 2           1761    True                None                None
# 3           1319    True                None                None
# 4           1761    True                None                None
# ...          ...     ...                 ...                 ...
# 14063        168    True                None                None
# 14064        168    True                None                None
# 14065        273    True                None                None
# 14066         71    True                None                None
# 14067        169    True                None                None
#
#                                   parcel_id   Prop_ID
# 0      Collin_County_combined_parcel_100303   1140143
# 1       Collin_County_combined_parcel_10067   2712455
# 2      Collin_County_combined_parcel_100752   2529683
# 3      Collin_County_combined_parcel_101602   1105725
# 4      Collin_County_combined_parcel_102471   2529792
# ...                                     ...       ...
# 14063     Wise_County_combined_parcel_48085  781626.0
# 14064       Wise_County_combined_parcel_647  746915.0
# 14065      Wise_County_combined_parcel_7455  753228.0
# 14066      Wise_County_combined_parcel_8586  790473.0
# 14067      Wise_County_combined_parcel_9195  783634.0
#
# [14068 rows x 6 columns]

# %% [markdown]
# <!-- #### 05. `check_bedrooms` function
# - `get_zoning_req` function is integrated internally. -->

# %%
# check_bedrooms_result_all = check_zoning_process(tidybuilding_4_fam_wide, tidyzoning, confident_tidyparcel_dim, check_bedrooms, n_jobs=-1)
# check_bedrooms_result_all
# Out:
# Parallel Processing: 100%|██████████| 14068/14068 [05:32<00:00, 42.30it/s]
#        zoning_id  allowed constraint_min_note constraint_max_note  \
# 0           1319     True                None                None
# 1           1319     True                None                None
# 2           1761     True                None                None
# 3           1319     True                None                None
# 4           1761     True                None                None
# ...          ...      ...                 ...                 ...
# 14063        168     True                None                None
# 14064        168     True                None                None
# 14065        273     True                None                None
# 14066         71     True                None                None
# 14067        169     True                None                None
#
#                                   parcel_id   Prop_ID
# 0      Collin_County_combined_parcel_100303   1140143
# 1       Collin_County_combined_parcel_10067   2712455
# 2      Collin_County_combined_parcel_100752   2529683
# 3      Collin_County_combined_parcel_101602   1105725
# 4      Collin_County_combined_parcel_102471   2529792
# ...                                     ...       ...
# 14063     Wise_County_combined_parcel_48085  781626.0
# 14064       Wise_County_combined_parcel_647  746915.0
# 14065      Wise_County_combined_parcel_7455  753228.0
# 14066      Wise_County_combined_parcel_8586  790473.0
# 14067      Wise_County_combined_parcel_9195  783634.0
#
# [14068 rows x 6 columns]

# %% [markdown]
# <!-- #### 06. `check_lot_coverage` function
# - `get_zoning_req` function is integrated internally. -->

# %%
# check_lot_coverage_result_all = check_zoning_process(tidybuilding_4_fam_wide, tidyzoning, confident_tidyparcel_dim, check_lot_coverage, n_jobs=-1)
# check_lot_coverage_result_all
# Out:
# Parallel Processing: 100%|██████████| 14068/14068 [10:04<00:00, 23.27it/s]
#        zoning_id allowed constraint_min_note constraint_max_note  \
# 0           1319    True                None                None
# 1           1319    True                None                None
# 2           1761    True                None                None
# 3           1319    True                None                None
# 4           1761    True                None                None
# ...          ...     ...                 ...                 ...
# 14063        168    True                None                None
# 14064        168    True                None                None
# 14065        273    True                None                None
# 14066         71    True                None                None
# 14067        169    True                None                None
#
#                                   parcel_id   Prop_ID
# 0      Collin_County_combined_parcel_100303   1140143
# 1       Collin_County_combined_parcel_10067   2712455
# 2      Collin_County_combined_parcel_100752   2529683
# 3      Collin_County_combined_parcel_101602   1105725
# 4      Collin_County_combined_parcel_102471   2529792
# ...                                     ...       ...
# 14063     Wise_County_combined_parcel_48085  781626.0
# 14064       Wise_County_combined_parcel_647  746915.0
# 14065      Wise_County_combined_parcel_7455  753228.0
# 14066      Wise_County_combined_parcel_8586  790473.0
# 14067      Wise_County_combined_parcel_9195  783634.0
#
# [14068 rows x 6 columns]

# %% [markdown]
# <!-- #### 07. `check_unit_density` function
# - `get_zoning_req` function is integrated internally. -->

# %%
# check_unit_density_result_all = check_zoning_process(tidybuilding_4_fam_wide, tidyzoning, confident_tidyparcel_dim, check_unit_density, n_jobs=-1)
# check_unit_density_result_all
# Out:
# Parallel Processing:   0%|          | 0/14068 [00:00<?, ?it/s]
# Parallel Processing: 100%|██████████| 14068/14068 [05:46<00:00, 40.55it/s]
#        zoning_id allowed constraint_min_note constraint_max_note  \
# 0           1319    True                None                None
# 1           1319    True                None                None
# 2           1761   False                None                None
# 3           1319    True                None                None
# 4           1761   False                None                None
# ...          ...     ...                 ...                 ...
# 14063        168    True                None                None
# 14064        168    True                None                None
# 14065        273    True                None                None
# 14066         71    True                None                None
# 14067        169    True                None                None
#
#                                   parcel_id   Prop_ID
# 0      Collin_County_combined_parcel_100303   1140143
# 1       Collin_County_combined_parcel_10067   2712455
# 2      Collin_County_combined_parcel_100752   2529683
# 3      Collin_County_combined_parcel_101602   1105725
# 4      Collin_County_combined_parcel_102471   2529792
# ...                                     ...       ...
# 14063     Wise_County_combined_parcel_48085  781626.0
# 14064       Wise_County_combined_parcel_647  746915.0
# 14065      Wise_County_combined_parcel_7455  753228.0
# 14066      Wise_County_combined_parcel_8586  790473.0
# 14067      Wise_County_combined_parcel_9195  783634.0
#
# [14068 rows x 6 columns]

# %% [markdown]
# <!-- #### 08. `check_unit_size` function
# - `get_zoning_req` function is integrated internally. -->

# %%
# check_unit_size_result_all = check_zoning_process(tidybuilding_4_fam_wide, tidyzoning, confident_tidyparcel_dim, check_unit_size, n_jobs=-1)
# check_unit_size_result_all
# Out:
# Parallel Processing: 100%|██████████| 14068/14068 [05:47<00:00, 40.46it/s]
#        zoning_id allowed constraint_min_note constraint_max_note  \
# 0           1319    True                None                None
# 1           1319    True                None                None
# 2           1761   False                None                None
# 3           1319    True                None                None
# 4           1761   False                None                None
# ...          ...     ...                 ...                 ...
# 14063        168    True                None                None
# 14064        168    True                None                None
# 14065        273    True                None                None
# 14066         71    True                None                None
# 14067        169    True                None                None
#
#                                   parcel_id   Prop_ID
# 0      Collin_County_combined_parcel_100303   1140143
# 1       Collin_County_combined_parcel_10067   2712455
# 2      Collin_County_combined_parcel_100752   2529683
# 3      Collin_County_combined_parcel_101602   1105725
# 4      Collin_County_combined_parcel_102471   2529792
# ...                                     ...       ...
# 14063     Wise_County_combined_parcel_48085  781626.0
# 14064       Wise_County_combined_parcel_647  746915.0
# 14065      Wise_County_combined_parcel_7455  753228.0
# 14066      Wise_County_combined_parcel_8586  790473.0
# 14067      Wise_County_combined_parcel_9195  783634.0
#
# [14068 rows x 6 columns]

# %% [markdown]
# <!-- #### 09. `check_stories` function
# - `get_zoning_req` function is integrated internally. -->

# %%
# check_stories_result_all = check_zoning_process(tidybuilding_4_fam_wide, tidyzoning, confident_tidyparcel_dim, check_stories, n_jobs=-1)
# check_stories_result_all
# Out:
# Parallel Processing: 100%|██████████| 14068/14068 [05:39<00:00, 41.48it/s]
#        zoning_id allowed constraint_min_note constraint_max_note  \
# 0           1319    True                None                None
# 1           1319    True                None                None
# 2           1761    True                None                None
# 3           1319    True                None                None
# 4           1761    True                None                None
# ...          ...     ...                 ...                 ...
# 14063        168    True                None                None
# 14064        168    True                None                None
# 14065        273    True                None                None
# 14066         71    True                None                None
# 14067        169    True                None                None
#
#                                   parcel_id   Prop_ID
# 0      Collin_County_combined_parcel_100303   1140143
# 1       Collin_County_combined_parcel_10067   2712455
# 2      Collin_County_combined_parcel_100752   2529683
# 3      Collin_County_combined_parcel_101602   1105725
# 4      Collin_County_combined_parcel_102471   2529792
# ...                                     ...       ...
# 14063     Wise_County_combined_parcel_48085  781626.0
# 14064       Wise_County_combined_parcel_647  746915.0
# 14065      Wise_County_combined_parcel_7455  753228.0
# 14066      Wise_County_combined_parcel_8586  790473.0
# 14067      Wise_County_combined_parcel_9195  783634.0
#
# [14068 rows x 6 columns]

# %% [markdown]
# <!-- #### 10. `check_height_eave` function
# - `get_zoning_req` function is integrated internally. -->

# %%
# check_height_eave_result_all = check_zoning_process(tidybuilding_4_fam_wide, tidyzoning, confident_tidyparcel_dim, check_height_eave, n_jobs=-1)
# check_height_eave_result_all
# Out:
# Parallel Processing: 100%|██████████| 14068/14068 [10:29<00:00, 22.33it/s]
#        zoning_id  allowed constraint_min_note constraint_max_note  \
# 0           1319     True                None                None
# 1           1319     True                None                None
# 2           1761     True                None                None
# 3           1319     True                None                None
# 4           1761     True                None                None
# ...          ...      ...                 ...                 ...
# 14063        168     True                None                None
# 14064        168     True                None                None
# 14065        273     True                None                None
# 14066         71     True                None                None
# 14067        169     True                None                None
#
#                                   parcel_id   Prop_ID
# 0      Collin_County_combined_parcel_100303   1140143
# 1       Collin_County_combined_parcel_10067   2712455
# 2      Collin_County_combined_parcel_100752   2529683
# 3      Collin_County_combined_parcel_101602   1105725
# 4      Collin_County_combined_parcel_102471   2529792
# ...                                     ...       ...
# 14063     Wise_County_combined_parcel_48085  781626.0
# 14064       Wise_County_combined_parcel_647  746915.0
# 14065      Wise_County_combined_parcel_7455  753228.0
# 14066      Wise_County_combined_parcel_8586  790473.0
# 14067      Wise_County_combined_parcel_9195  783634.0
#
# [14068 rows x 6 columns]

# %% [markdown]
# <!-- #### 11. `check_unit_qty` function
# - `get_zoning_req` function is integrated internally. -->

# %%
# check_unit_qty_result_all = check_zoning_process(tidybuilding_4_fam_wide, tidyzoning, confident_tidyparcel_dim, check_unit_qty, n_jobs=-1)
# check_unit_qty_result_all
# Out:
# Parallel Processing: 100%|██████████| 14068/14068 [10:13<00:00, 22.94it/s]
#        zoning_id  allowed constraint_min_note constraint_max_note  \
# 0           1319     True                None                None
# 1           1319     True                None                None
# 2           1761     True                None                None
# 3           1319     True                None                None
# 4           1761     True                None                None
# ...          ...      ...                 ...                 ...
# 14063        168     True                None                None
# 14064        168     True                None                None
# 14065        273     True                None                None
# 14066         71     True                None                None
# 14067        169     True                None                None
#
#                                   parcel_id   Prop_ID
# 0      Collin_County_combined_parcel_100303   1140143
# 1       Collin_County_combined_parcel_10067   2712455
# 2      Collin_County_combined_parcel_100752   2529683
# 3      Collin_County_combined_parcel_101602   1105725
# 4      Collin_County_combined_parcel_102471   2529792
# ...                                     ...       ...
# 14063     Wise_County_combined_parcel_48085  781626.0
# 14064       Wise_County_combined_parcel_647  746915.0
# 14065      Wise_County_combined_parcel_7455  753228.0
# 14066      Wise_County_combined_parcel_8586  790473.0
# 14067      Wise_County_combined_parcel_9195  783634.0
#
# [14068 rows x 6 columns]

# %% [markdown]
# <!-- ### Statistics figure of allowed parcels in each check function -->

# %%
# # Assume check_results is defined as in your code snippet:
# check_results = {
#     "height": check_height_result_all,
#     "height_eave": check_height_eave_result_all,
#     "stories": check_stories_result_all,
#     "unit_size": check_unit_size_result_all,
#     "far": check_far_result_all,
#     "unit_density": check_unit_density_result_all,
#     "lot_coverage": check_lot_coverage_result_all,
#     "fl_area": check_fl_area_result_all,
#     "bedrooms": check_bedrooms_result_all,
#     "unit_qty": check_unit_qty_result_all,
# }

# # Initialize the summary dictionary with keys for each column
# summary = {
#     "Label": [],
#     "True": [],
#     "False": [],
#     "MAYBE": []
# }

# # Iterate over each DataFrame in the dictionary and capture counts
# for label, df in check_results.items():
#     allowed_counts = df["allowed"].value_counts()
#     summary["Label"].append(label)
#     # Note: if a key doesn't exist in value_counts, default to 0
#     summary["True"].append(allowed_counts.get(True, 0))
#     summary["False"].append(allowed_counts.get(False, 0))
#     summary["MAYBE"].append(allowed_counts.get("MAYBE", 0))

# # Convert the summary dictionary into a pandas DataFrame
# summary_df = pd.DataFrame(summary)
# summary_df
# Out:
#           Label   True  False  MAYBE
# 0        height   9249   4492    327
# 1   height_eave  14068      0      0
# 2       stories  13113    805    150
# 3     unit_size  13442    623      3
# 4           far  13869    199      0
# 5  unit_density  12240   1824      4
# 6  lot_coverage  13012   1049      7
# 7       fl_area  14068      0      0
# 8      bedrooms  14068      0      0
# 9      unit_qty  14062      6      0

# %%
import pandas as pd

# Suppose these are your pre-defined DataFrames for each check
check_results = {
    "height": check_height_result_all,
    "height_eave": check_height_eave_result_all,
    "stories": check_stories_result_all,
    "unit_size": check_unit_size_result_all,
    "far": check_far_result_all,
    "unit_density": check_unit_density_result_all,
    "lot_coverage": check_lot_coverage_result_all,
    "fl_area": check_fl_area_result_all,
    "bedrooms": check_bedrooms_result_all,
    "unit_qty": check_unit_qty_result_all,
}

# Initialize the summary dictionary
summary = {
    "Label": [],
    "True": [],
    "False": [],
    "MAYBE": []
}

# Iterate over the results and count each allowed status
for label, df in check_results.items():
    # Get value counts for the 'allowed' column
    allowed_counts = df["allowed"].value_counts()
    
    # Append the name and counts, with default to 0 if not found
    summary["Label"].append(label)
    summary["True"].append(allowed_counts.get(True, 0))
    summary["False"].append(allowed_counts.get(False, 0))
    summary["MAYBE"].append(allowed_counts.get("MAYBE", 0))

# Convert the summary dictionary into a DataFrame
summary_df = pd.DataFrame(summary)

# Display the summary table
print(summary_df)

# %% [markdown]
# <!-- ### `add_setbacks` function
# - `get_zoning_req` function is integrated internally. -->

# %%
# file_path = r"/Users/houpuli/Dropbox/ceshi/tidybuilding/2_fam/"
# tidybuilding_2_fam = unify_tidybuilding(file_path)
# tidybuilding_2_fam
# Out:
#    stories  height  width  depth  height_eave      type  gross_fl_area  \
# 0      2.5      45     35     40           35  2_family           3200
#
#    net_fl_area  max_unit_size  min_unit_size  mean_unit_size  total_bedrooms  \
# 0         3126           1563           1563            1563               6
#
#    total_units  footprint  units_3bed  units_3bed_minsize  units_3bed_maxsize  \
# 0            2       1400           2                1563                1563
#
#    units_floor1  units_floor2  units_floor3
# 0             2             0             0

# %%
# # Example usage:
# add_setbacks_results = add_setbacks(tidybuilding_2_fam, tidyzoning_feeds.loc[[373]], tidyparcel_dim[tidyparcel_dim['parcel_id'] == 'Collin_County_combined_parcel_102719'], tidyparcel_geo[tidyparcel_geo['parcel_id'] == 'Collin_County_combined_parcel_102719'])
# add_setbacks_results
# Out:
#        Prop_ID             GEO_ID                             parcel_id  \
# 14139  2503294  R-5140-00E-0090-1  Collin_County_combined_parcel_102719
# 14140  2503294  R-5140-00E-0090-1  Collin_County_combined_parcel_102719
# 14141  2503294  R-5140-00E-0090-1  Collin_County_combined_parcel_102719
# 14142  2503294  R-5140-00E-0090-1  Collin_County_combined_parcel_102719
# 14143  2503294  R-5140-00E-0090-1  Collin_County_combined_parcel_102719
#
#           parcel_addr landuse landuse_spec             parcel_label  \
# 14139  890   DERBY CT       R           A1  cul_de_sac parcel_other
# 14140  890   DERBY CT       R           A1  cul_de_sac parcel_other
# 14141  890   DERBY CT       R           A1  cul_de_sac parcel_other
# 14142  890   DERBY CT       R           A1  cul_de_sac parcel_other
# 14143  890   DERBY CT       R           A1  cul_de_sac parcel_other
#
#       Found_Match match_road_address  shape_index  ...  shared_side  \
# 14139        True           Derby Ct     1.164104  ...        False
# 14140        True           Derby Ct     1.164104  ...         True
# 14141        True           Derby Ct     1.164104  ...         True
# 14142        True           Derby Ct     1.164104  ...         True
# 14143        True           Derby Ct     1.164104  ...        False
#
#        parcel_bearing  road_bearing      angle  distance_to_road  \
# 14139       -2.732984     -0.000002  23.411678         16.169501
# 14140       -1.805070     -0.000002  76.577216         35.714161
# 14141       -0.006169     -0.000002   0.353327         53.093845
# 14142        1.577510     -0.000002  89.615248         31.418836
# 14143       -3.138775     -0.000002   0.161550          9.632050
#
#                 side                                           geometry  \
# 14139          front  LINESTRING (1297967.613 1242664.136, 1297965.5...
# 14140  Interior side  LINESTRING (1297973.690 1242693.165, 1297973.6...
# 14141           rear  LINESTRING (1297937.939 1242692.349, 1297961.2...
# 14142  Interior side  LINESTRING (1297939.234 1242656.113, 1297937.9...
# 14143          front  LINESTRING (1297951.203 1242656.493, 1297939.2...
#
#        setback  unit on_boundary
# 14139     10.0  feet       False
# 14140      5.0  feet       False
# 14141     20.0  feet       False
# 14142      5.0  feet       False
# 14143     10.0  feet       False
#
# [5 rows x 23 columns]

# %% [markdown]
# <!-- ### `get_buildable_area` function
# - `get_zoning_req` function is integrated internally. -->

# %%
# # Example usage:
# add_setbacks_results = add_setbacks(tidybuilding_4_fam_wide, tidyzoning.loc[[2]], confident_tidyparcel_dim[confident_tidyparcel_dim['parcel_id'] == 'Collin_County_combined_parcel_10000'], confident_tidyparcel[confident_tidyparcel['parcel_id'] == 'Collin_County_combined_parcel_10000'])
# add_setbacks_results
# Out:
#    Prop_ID              GEO_ID                            parcel_id  \
# 0  2747493  R-11137-00A-0150-1  Collin_County_combined_parcel_10000
# 1  2747493  R-11137-00A-0150-1  Collin_County_combined_parcel_10000
# 2  2747493  R-11137-00A-0150-1  Collin_County_combined_parcel_10000
# 3  2747493  R-11137-00A-0150-1  Collin_County_combined_parcel_10000
#
#            parcel_addr landuse landuse_spec           parcel_label  \
# 0  8816   ABBINGTON PL       R           A1  regular inside parcel
# 1  8816   ABBINGTON PL       R           A1  regular inside parcel
# 2  8816   ABBINGTON PL       R           A1  regular inside parcel
# 3  8816   ABBINGTON PL       R           A1  regular inside parcel
#
#   Found_Match match_road_address  shape_index  ...  angle_difference  \
# 0        True       Abbington Pl     1.284231  ...          0.201639
# 1        True       Abbington Pl     1.284231  ...          0.201639
# 2        True       Abbington Pl     1.284231  ...          0.201639
# 3        True       Abbington Pl     1.284231  ...          0.201639
#
#    shared_side  parcel_bearing  road_bearing      angle  distance_to_road  \
# 0         True       -1.571972     -0.006727  89.681925         36.761265
# 1         True       -0.003207     -0.006727   0.201640         62.382758
# 2         True        1.569623     -0.006727  89.681813         36.697407
# 3        False        3.138385     -0.006727   0.201639         11.075914
#
#             side                                           geometry   setback  \
# 0  Interior side  LINESTRING (-10768051.845 3919309.968, -107680...  [20, 15]
# 1           rear  LINESTRING (-10768069.990 3919310.026, -107680...        25
# 2  Interior side  LINESTRING (-10768070.050 3919258.718, -107680...  [20, 15]
# 3          front  LINESTRING (-10768051.905 3919258.660, -107680...  [50, 30]
#
#    unit
# 0  feet
# 1  feet
# 2  feet
# 3  feet
#
# [4 rows x 22 columns]

# %%
# get_buildable_area_result = get_buildable_area(add_setbacks_results)
# get_buildable_area_result
# Out:
#    Prop_ID                            parcel_id  \
# 0  2747493  Collin_County_combined_parcel_10000
#
#                         buildable_geometry_relaxable  \
# 0  POLYGON ((-10768065.467793169 3919267.84744810...
#
#                            buildable_geometry_strict
# 0  POLYGON ((-10768063.937 3919273.939, -10768063...

# %%
# import matplotlib.pyplot as plt
# import matplotlib.lines as mlines

# # Define a mapping from 'side' values to colors.
# color_mapping = {
#     'Interior side': 'red',
#     'Exterior side': 'blue',
#     'rear': 'green',
#     'front': 'orange'
# }

# fig, ax = plt.subplots(figsize=(10, 10))

# # Plot the setbacks results by grouping based on the 'side' column.
# for side, group in add_setbacks_results.groupby('side'):
#     group.plot(
#         ax=ax, 
#         color=None, 
#         alpha=1, 
#         edgecolor=color_mapping.get(side, 'black'), 
#         linewidth=5, 
#         label=f'Parcels with setbacks ({side})'
#     )

# # Plot the strict buildable area.
# strict_area = get_buildable_area_result.copy().set_geometry('buildable_geometry_strict')
# strict_area.plot(
#     ax=ax, 
#     color='red', 
#     alpha=0.5, 
#     edgecolor='black', 
#     label='Strict Buildable Area'
# )

# # Plot the relaxable buildable area.
# relaxable_area = get_buildable_area_result.copy().set_geometry('buildable_geometry_relaxable')
# relaxable_area.plot(
#     ax=ax, 
#     color='blue', 
#     alpha=0.5, 
#     edgecolor='black', 
#     label='Relaxable Buildable Area'
# )

# # Create custom legend handles.
# handles = []
# # Add legend handles for each setbacks side.
# for side in add_setbacks_results['side'].unique():
#     color = color_mapping.get(side, 'black')
#     handle = mlines.Line2D([], [], color=color, linewidth=5, label=f'Parcels with setbacks ({side})')
#     handles.append(handle)
# # Add handles for the buildable area layers.
# handles.append(mlines.Line2D([], [], color='red', marker='s', markersize=10,
#                              markerfacecolor='red', linestyle='None',
#                              label='Strict Buildable Area'))
# handles.append(mlines.Line2D([], [], color='blue', marker='s', markersize=10,
#                              markerfacecolor='blue', linestyle='None',
#                              label='Relaxable Buildable Area'))

# ax.legend(handles=handles, loc='upper right', bbox_to_anchor=(2.2, 1))
# plt.show()

# %% [markdown]
# <!-- ### `check_footprint()` function
# - Based on Matt's Way -->

# %%
# check_footprint_results = check_footprint(get_buildable_area_result, tidybuilding_4_fam_wide)
# check_footprint_results
# Out:
# Processing Parcels: 100%|██████████| 1/1 [00:00<00:00,  1.77it/s]
#    Prop_ID                            parcel_id  allowed
# 0  2747493  Collin_County_combined_parcel_10000    False

# %% [markdown]
# <!-- ### Run Code by steps -->

# %% [markdown]
# <!-- ### Run Code summariezed function -->

# %% [markdown]
# <!-- #### Statistic in each check function -->

# %% [markdown]
# <!-- ##### Check the land use -->

# %%
# from collections import Counter

# # Extract uses_value, ensuring it is of list type
# uses_values_list = tidyzoning['dist_info'].apply(
#     lambda x: x.get('uses_permitted', {}).get('uses_value', [])
# )

# # Handle exceptional cases: if `uses_value` is a string, convert it to a list
# cleaned_uses_values = uses_values_list.apply(lambda x: [x] if isinstance(x, str) else x)

# # Calculate all unique uses_value
# unique_uses_values = set(value for sublist in cleaned_uses_values for value in sublist)

# # Count the occurrences of each uses_value
# counts = Counter()
# for uses in cleaned_uses_values:
#     counts.update(uses)

# # Create a DataFrame to calculate the percentage
# counts_df = pd.DataFrame.from_dict(counts, orient='index', columns=['count'])
# counts_df['percentage'] = counts_df['count'] / len(tidyzoning) * 100
# counts_df
# Out:
#                                  count  percentage
# 1_family                           114   40.569395
# ADU                                103   36.654804
# 2_family                            45   16.014235
# 3_family                            44   15.658363
# 4_family                            45   16.014235
# Townhome                            48   17.081851
# none                               115   40.925267
# Planned_Residential_Development     11    3.914591

# %% [markdown]
# <!-- ##### Check the fl_area -->

# %%
# fl_area_constraints = tidyzoning['structure_constraints'].apply(
#     lambda x: {key: value for key, value in x.items() if 'fl_area' in key.lower()} if isinstance(x, dict) else {}
# )
# fl_area_constraints
# Out:
# 0      {}
# 1      {}
# 2      {}
# 3      {}
# 4      {}
#        ..
# 276    {}
# 277    {}
# 278    {}
# 279    {}
# 280    {}
# Name: structure_constraints, Length: 281, dtype: object

# %% [markdown]
# <!-- ##### Check the height -->

# %%
# height_constraints = tidyzoning['structure_constraints'].apply(
#     lambda x: {key: value for key, value in x.items() if 'height' in key.lower()} if isinstance(x, dict) else {}
# )
# height_constraints
# Out:
# 0                                                     {}
# 1                                                     {}
# 2                                                     {}
# 3                                                     {}
# 4                                                     {}
#                              ...
# 276                                                   {}
# 277                                                   {}
# 278                                                   {}
# 279    {'height': [{'unit': 'feet', 'use_name': '1_fa...
# 280                                                   {}
# Name: structure_constraints, Length: 281, dtype: object

# %%
# import seaborn as sns

# # Step 1: Parse height data
# height_data = []
# for constraints in height_constraints:
#     if isinstance(constraints, dict) and 'height' in constraints:
#         for entry in constraints['height']:
#             use_names = entry.get('use_name', [])
#             max_val = entry.get('max_val')

#             # Handle max_val: it could be a dictionary or a list
#             if isinstance(max_val, list):  # Handle case where max_val is a list
#                 max_val = max_val[0] if len(max_val) > 0 else {}
            
#             # Extract height value
#             if isinstance(max_val, dict):
#                 if 'expression' in max_val:
#                     height_value = max_val['expression']
#                 elif 'expressions' in max_val:
#                     height_value = max(max_val['expressions'])  # Take the maximum value
#                 else:
#                     height_value = None
#             else:
#                 height_value = None

#             # Ensure use_names is a list
#             if isinstance(use_names, str):
#                 use_names = [use_names]

#             # Record data
#             if height_value:
#                 for use in use_names:
#                     try:
#                         height_data.append({'use_name': use, 'height': float(height_value)})
#                     except ValueError:
#                         pass  # Ignore values that cannot be converted

# # Step 2: Convert to DataFrame
# height_df = pd.DataFrame(height_data)

# # Step 3: Keep only the housing types of interest
# selected_types = ['1_family', '2_family', '3_family', '4_family', 'Townhome']
# filtered_df = height_df[height_df['use_name'].isin(selected_types)]

# # Step 4: Plot boxplot
# plt.figure(figsize=(8, 5))
# sns.boxplot(x='use_name', y='height', data=filtered_df, palette="Set3")

# # Step 5: Add reference lines
# for y_value, color, label in zip([45, 40, 38, 60], ['red', 'green', 'purple', 'orange'], ['y=45', 'y=40', 'y=38', 'y=60']):
#     plt.axhline(y=y_value, color=color, linestyle='--', label=label)

# # Step 6: Beautify the chart
# plt.xlabel("Use Type")
# plt.ylabel("Max Height (feet)")
# plt.title("Max Height Distribution by Use Type")
# plt.legend()
# plt.xticks(rotation=30)

# # Step 7: Show the chart
# plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_24888\1675141653.py:47: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='use_name', y='height', data=filtered_df, palette="Set3")

# %% [markdown]
# <!-- ##### Check the bedrooms -->

# %%
# bedrooms_constraints = tidyzoning['structure_constraints'].apply(
#     lambda x: {key: value for key, value in x.items() if 'bedrooms' in key.lower()} if isinstance(x, dict) else {}
# )
# bedrooms_constraints
# Out:
# 0      {}
# 1      {}
# 2      {}
# 3      {}
# 4      {}
#        ..
# 276    {}
# 277    {}
# 278    {}
# 279    {}
# 280    {}
# Name: structure_constraints, Length: 281, dtype: object

# %% [markdown]
# <!-- ##### Check the unit density -->

# %%
# unit_density_constraints = tidyzoning['structure_constraints'].apply(
#     lambda x: {key: value for key, value in x.items() if 'unit_density' in key.lower()} if isinstance(x, dict) else {}
# )
# unit_density_constraints
# Out:
# 0      {}
# 1      {}
# 2      {}
# 3      {}
# 4      {}
#        ..
# 276    {}
# 277    {}
# 278    {}
# 279    {}
# 280    {}
# Name: structure_constraints, Length: 281, dtype: object

# %%
# import seaborn as sns

# # Step 1: Parse unit_density data
# unit_density_data = []
# for constraints in unit_density_constraints:
#     if isinstance(constraints, dict) and 'unit_density' in constraints:
#         for entry in constraints['unit_density']:
#             use_names = entry.get('use_name', [])
#             max_val = entry.get('max_val')

#             # Handle max_val: it could be a dictionary or a list
#             if isinstance(max_val, list):  # Handle case where max_val is a list
#                 max_val = max_val[0] if len(max_val) > 0 else {}
            
#             # Extract unit_density value
#             if isinstance(max_val, dict):
#                 if 'expression' in max_val:
#                     unit_density_value = max_val['expression']
#                 elif 'expressions' in max_val:
#                     unit_density_value = max(max_val['expressions'])  # Take the maximum value
#                 else:
#                     unit_density_value = None
#             else:
#                 unit_density_value = None

#             # Ensure use_names is a list
#             if isinstance(use_names, str):
#                 use_names = [use_names]

#             # Record data
#             if unit_density_value:
#                 for use in use_names:
#                     try:
#                         unit_density_data.append({'use_name': use, 'unit_density': float(unit_density_value)})
#                     except ValueError:
#                         pass  # Ignore values that cannot be converted

# # Step 2: Convert to DataFrame
# unit_density_df = pd.DataFrame(unit_density_data)

# # Step 3: Keep only the housing types of interest
# selected_types = ['1_family', '2_family', '3_family', '4_family', 'Townhome']
# filtered_df = unit_density_df[unit_density_df['use_name'].isin(selected_types)]

# # Step 4: Plot boxplot
# plt.figure(figsize=(8, 5))
# sns.boxplot(x='use_name', y='unit_density', data=filtered_df, palette="Set3")

# # Step 5: Beautify the chart
# plt.xlabel("Use Type")
# plt.ylabel("Max Unit_Density (du/acre)")
# plt.title("Max Unit_Density Distribution by Use Type")
# plt.legend()
# plt.xticks(rotation=30)

# # Step 7: Show the chart
# plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_24888\2265464215.py:47: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='use_name', y='unit_density', data=filtered_df, palette="Set3")
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# <!-- ##### Check the unit size -->

# %%
# unit_size_constraints = tidyzoning['structure_constraints'].apply(
#     lambda x: {key: value for key, value in x.items() if 'unit_size' in key.lower()} if isinstance(x, dict) else {}
# )
# unit_size_constraints
# Out:
# 0      {'unit_size': [{'unit': 'square feet', 'use_na...
# 1      {'unit_size': [{'unit': 'square feet', 'use_na...
# 2      {'unit_size': [{'unit': 'square feet', 'use_na...
# 3                                                     {}
# 4                                                     {}
#                              ...
# 276                                                   {}
# 277                                                   {}
# 278                                                   {}
# 279                                                   {}
# 280                                                   {}
# Name: structure_constraints, Length: 281, dtype: object

# %%
# import seaborn as sns
# import re

# # Step 1: Parse unit_size data
# unit_size_data = []
# bedrooms = 6  # Default bedrooms=6

# for constraints in unit_size_constraints:
#     if isinstance(constraints, dict) and 'unit_size' in constraints:
#         for entry in constraints['unit_size']:
#             use_names = entry.get('use_name', [])
#             min_val = entry.get('min_val')

#             # Handle min_val: it could be a dictionary or a list
#             if isinstance(min_val, list):  
#                 min_val = min_val[0] if len(min_val) > 0 else {}

#             # Extract expression
#             if isinstance(min_val, dict) and 'expression' in min_val:
#                 raw_expr = min_val['expression']
                
#                 # Skip "NA" values
#                 if raw_expr == 'NA':
#                     continue
                
#                 # Handle "0/1 BR: 600; 2 BR: 800; 3BR: 1000"
#                 if re.search(r'3BR:\s*\d+', raw_expr):
#                     match = re.search(r'3BR:\s*(\d+)', raw_expr)
#                     unit_size_value = float(match.group(1)) if match else None
                
#                 # Handle "800 + 150 * bedrooms" calculation
#                 elif re.search(r'bedrooms', raw_expr):
#                     try:
#                         unit_size_value = eval(raw_expr.replace("bedrooms", str(bedrooms)))
#                     except:
#                         unit_size_value = None
                
#                 # Handle regular numeric values
#                 else:
#                     try:
#                         unit_size_value = float(raw_expr)
#                     except ValueError:
#                         unit_size_value = None
#             else:
#                 unit_size_value = None

#             # Ensure use_names is a list
#             if isinstance(use_names, str):
#                 use_names = [use_names]

#             # Record data
#             if unit_size_value:
#                 for use in use_names:
#                     try:
#                         unit_size_data.append({'use_name': use, 'unit_size': unit_size_value})
#                     except ValueError:
#                         pass  # Ignore values that cannot be converted
                    
# # Step 2: Convert to DataFrame
# unit_size_df = pd.DataFrame(unit_size_data)

# # Step 3: Keep only the housing types of interest
# selected_types = ['1_family', '2_family', '3_family', '4_family', 'Townhome']
# filtered_df = unit_size_df[unit_size_df['use_name'].isin(selected_types)]

# # Step 4: Plot boxplot
# plt.figure(figsize=(8, 5))
# sns.boxplot(x='use_name', y='unit_size', data=filtered_df, palette="Set3")

# # Step 5: Beautify the chart
# plt.xlabel("Use Type")
# plt.ylabel("Min Unit_Size (ft2)")
# plt.title("Min Unit_Size Distribution by Use Type")
# plt.legend()
# plt.xticks(rotation=30)

# # Step 7: Show the chart
# plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_24888\513548288.py:68: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='use_name', y='unit_size', data=filtered_df, palette="Set3")
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# <!-- ##### Check the Far -->

# %%
# far_constraints = tidyzoning['structure_constraints'].apply(
#     lambda x: {key: value for key, value in x.items() if 'far' in key.lower()} if isinstance(x, dict) else {}
# )
# far_constraints
# Out:
# 0      {}
# 1      {}
# 2      {}
# 3      {}
# 4      {}
#        ..
# 276    {}
# 277    {}
# 278    {}
# 279    {}
# 280    {}
# Name: structure_constraints, Length: 281, dtype: object

# %%
# import seaborn as sns

# # Step 1: Parse far data
# far_data = []
# for constraints in far_constraints:
#     if isinstance(constraints, dict) and 'far' in constraints:
#         for entry in constraints['far']:
#             use_names = entry.get('use_name', [])
#             max_val = entry.get('max_val')

#             # Handle max_val: it could be a dictionary or a list
#             if isinstance(max_val, list):  # Handle case where max_val is a list
#                 max_val = max_val[0] if len(max_val) > 0 else {}
            
#             # Extract far value
#             if isinstance(max_val, dict):
#                 if 'expression' in max_val:
#                     far_value = max_val['expression']
#                 elif 'expressions' in max_val:
#                     far_value = max(max_val['expressions'])  # Take the maximum value
#                 else:
#                     far_value = None
#             else:
#                 far_value = None

#             # Ensure use_names is a list
#             if isinstance(use_names, str):
#                 use_names = [use_names]

#             # Record data
#             if far_value:
#                 for use in use_names:
#                     try:
#                         far_data.append({'use_name': use, 'far': float(far_value)})
#                     except ValueError:
#                         pass  # Ignore values that cannot be converted

# # Step 2: Convert to DataFrame
# far_df = pd.DataFrame(far_data)

# # Step 3: Keep only the housing types of interest
# selected_types = ['1_family', '2_family', '3_family', '4_family', 'Townhome']
# filtered_df = far_df[far_df['use_name'].isin(selected_types)]

# # Step 4: Plot boxplot
# plt.figure(figsize=(8, 5))
# sns.boxplot(x='use_name', y='far', data=filtered_df, palette="Set3")

# # Step 5: Beautify the chart
# plt.xlabel("Use Type")
# plt.ylabel("Max far")
# plt.title("Max far Distribution by Use Type")
# plt.legend()
# plt.xticks(rotation=30)

# # Step 7: Show the chart
# plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_24888\2235503832.py:47: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='use_name', y='far', data=filtered_df, palette="Set3")
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# <!-- ##### Check the Lot_coverage -->

# %%
# lot_coverage_constraints = tidyzoning['structure_constraints'].apply(
#     lambda x: {key: value for key, value in x.items() if 'lot_coverage' in key.lower()} if isinstance(x, dict) else {}
# )
# lot_coverage_constraints
# Out:
# 0      {}
# 1      {}
# 2      {}
# 3      {}
# 4      {}
#        ..
# 276    {}
# 277    {}
# 278    {}
# 279    {}
# 280    {}
# Name: structure_constraints, Length: 281, dtype: object

# %% [markdown]
# <!-- ### `zoning_analysis_pipeline` functions
#
# - 00.check_land_use
# - 01.check_height
# - 02.check_stories
# - 03.check_unit_size
# - 04.check_far
# - 05.check_unit_density
# - 06.check_bedrooms
# - 07.check_lot_coverage
# - 08.check_fl_area -->

# %%
# tidybuilding_4_famtall_result_25 = zoning_analysis_pipeline(tidybuilding_4_fam_wide, part_tidyzoning_3081, tidyparcel_3081, confident_tidyparcel_3081,
#                                                             detailed_check = False,
#                                                             run_check_footprint = True)

# tidybuilding_4_famtall_result_25
# Out:
# check_land_use: 14068 / 345350 parcels allowed (4.1%)
# check_land_use runtime: 0.0 sec
# Running check_height: 100%|██████████| 14068/14068 [24:02<00:00,  9.75it/s]
# check_height          Survive: 14068/14068 (100.0%)True: 9249 ( 65.7%)MAYBE:  327 (  2.3%)False: 4492 ( 31.9%)
# check_height runtime: 1443.3 sec
# Running check_height_eave: 100%|██████████| 9576/9576 [16:28<00:00,  9.69it/s]
# check_height_eave     Survive: 9576/14068 ( 68.1%)True: 9576 ( 68.1%)MAYBE:    0 (  0.0%)False:    0 (  0.0%)
# check_height_eave runtime: 988.5 sec
# Running check_stories: 100%|██████████| 9576/9576 [00:14<00:00, 668.17it/s]
# check_stories         Survive: 9576/14068 ( 68.1%)True: 9142 ( 65.0%)MAYBE:  103 (  0.7%)False:  331 (  2.4%)
# check_stories runtime: 14.3 sec
# Running check_unit_size: 100%|██████████| 9245/9245 [00:29<00:00, 312.27it/s]
# check_unit_size       Survive: 9245/14068 ( 65.7%)True: 8737 ( 62.1%)MAYBE:    3 (  0.0%)False:  505 (  3.6%)
# check_unit_size runtime: 29.6 sec
# Running check_far: 100%|██████████| 8740/8740 [14:51<00:00,  9.80it/s]
# check_far             Survive: 8740/14068 ( 62.1%)True: 8708 ( 61.9%)MAYBE:    0 (  0.0%)False:   32 (  0.2%)
# check_far runtime: 891.6 sec
# Running check_unit_density: 100%|██████████| 8708/8708 [00:12<00:00, 685.97it/s]
# check_unit_density    Survive: 8708/14068 ( 61.9%)True: 8120 ( 57.7%)MAYBE:    0 (  0.0%)False:  588 (  4.2%)
# check_unit_density runtime: 12.7 sec
# Running check_lot_coverage: 100%|██████████| 8120/8120 [13:58<00:00,  9.69it/s]
# check_lot_coverage    Survive: 8120/14068 ( 57.7%)True: 7671 ( 54.5%)MAYBE:    3 (  0.0%)False:  446 (  3.2%)
# check_lot_coverage runtime: 838.1 sec
# Running check_fl_area: 100%|██████████| 7674/7674 [13:21<00:00,  9.58it/s]
# check_fl_area         Survive: 7674/14068 ( 54.5%)True: 7674 ( 54.5%)MAYBE:    0 (  0.0%)False:    0 (  0.0%)
# check_fl_area runtime: 801.3 sec
# Running check_unit_qty: 100%|██████████| 7674/7674 [13:00<00:00,  9.83it/s]
# check_unit_qty        Survive: 7674/14068 ( 54.5%)True: 7669 ( 54.5%)MAYBE:    0 (  0.0%)False:    5 (  0.0%)
# check_unit_qty runtime: 780.9 sec
# Running check_footprint on 7669/14068 parcels
# check_footprint: 100%|██████████| 7669/7669 [19:44<00:00,  6.48it/s]
# check_footprint       Survive: 6147/14068 ( 43.7%)  True: 6062 ( 43.1%)  MAYBE:   85 (  0.6%)  False: 1522 ( 10.8%)
# check_footprint runtime: 1184.4 sec
# zoning_analysis_pipeline total runtime: 6989.0 sec
# 5954 / 345350 parcels fit the building
# 193 / 345350 parcels maybe fit the building
#          Prop_ID                             parcel_id  \
# 0        2747493   Collin_County_combined_parcel_10000
# 1        2702267  Collin_County_combined_parcel_100028
# 2        2082442  Collin_County_combined_parcel_100030
# 3        2129279  Collin_County_combined_parcel_100049
# 4        1262715  Collin_County_combined_parcel_100067
# ...          ...                                   ...
# 345345  781626.0     Wise_County_combined_parcel_48085
# 345346  746915.0       Wise_County_combined_parcel_647
# 345347  753228.0      Wise_County_combined_parcel_7455
# 345348  790473.0      Wise_County_combined_parcel_8586
# 345349  783634.0      Wise_County_combined_parcel_9195
#
#                    Parcel_label   lot_width   lot_depth  lot_area  zoning_id  \
# 0         regular inside parcel   49.798850  140.149905  0.160223       1318
# 1       special parcel_standard   92.356753  155.462562  0.330331       1462
# 2         regular inside parcel   75.976481  153.355275  0.257746       1318
# 3         regular inside parcel   88.756216  120.637375  0.244816       1451
# 4         regular corner parcel   72.942981  115.924629  0.194107        412
# ...                         ...         ...         ...       ...        ...
# 345345    regular corner parcel   99.861634   69.713292  0.159818        168
# 345346    regular corner parcel  334.613968  259.647001  1.991946        168
# 345347    regular inside parcel  218.694540  100.216355  0.433263        273
# 345348    regular corner parcel  771.376098  938.497464  5.223278         71
# 345349  special parcel_standard  273.157571  178.421926  0.973641        169
#
#                confidence  check_land_use check_height  ... check_far  \
# 0       confidence_parcel           False          NaN  ...       NaN
# 1       confidence_parcel           False          NaN  ...       NaN
# 2       confidence_parcel           False          NaN  ...       NaN
# 3       confidence_parcel           False          NaN  ...       NaN
# 4       confidence_parcel           False          NaN  ...       NaN
# ...                   ...             ...          ...  ...       ...
# 345345  confidence_parcel            True         True  ...      True
# 345346  confidence_parcel            True         True  ...      True
# 345347  confidence_parcel            True         True  ...      True
# 345348  confidence_parcel            True         True  ...      True
# 345349  confidence_parcel            True         True  ...      True
#
#        check_unit_density check_lot_coverage check_fl_area check_unit_qty  \
# 0                     NaN                NaN           NaN            NaN
# 1                     NaN                NaN           NaN            NaN
# 2                     NaN                NaN           NaN            NaN
# 3                     NaN                NaN           NaN            NaN
# 4                     NaN                NaN           NaN            NaN
# ...                   ...                ...           ...            ...
# 345345               True               True          True           True
# 345346               True               True          True           True
# 345347               True               True          True           True
# 345348               True               True          True           True
# 345349               True               True          True           True
#
#        has_false has_maybe allowed                             reason  \
# 0              1         0   False  FALSE encountered: check_land_use
# 1              1         0   False  FALSE encountered: check_land_use
# 2              1         0   False  FALSE encountered: check_land_use
# 3              1         0   False  FALSE encountered: check_land_use
# 4              1         0   False  FALSE encountered: check_land_use
# ...          ...       ...     ...                                ...
# 345345         0         0    True           parcels fit the building
# 345346         0         0    True           parcels fit the building
# 345347         0         0    True           parcels fit the building
# 345348         0         0    True           parcels fit the building
# 345349         0         0    True           parcels fit the building
#
#         check_footprint
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 345345             True
# 345346             True
# 345347             True
# 345348             True
# 345349             True
#
# [345350 rows x 23 columns]

# %%
# # Merge the output cvs DataFrame with the geometry from tidyparcel_geo_feeds
# tidybuilding_4_famtall_result_25_geo = tidybuilding_4_famtall_result_25.merge(confident_tidyparcel_3081[confident_tidyparcel_3081['side'] == 'centroid'][['parcel_id', 'geometry']], on='parcel_id', how='left')

# # Convert the merged DataFrame into a GeoDataFrame
# tidybuilding_4_famtall_result_25_geo = gpd.GeoDataFrame(tidybuilding_4_famtall_result_25_geo, geometry='geometry', crs=confident_tidyparcel_3081.crs)
# tidybuilding_4_famtall_result_25_geo
# Out:
#          Prop_ID                             parcel_id  \
# 0        2747493   Collin_County_combined_parcel_10000
# 1        2702267  Collin_County_combined_parcel_100028
# 2        2082442  Collin_County_combined_parcel_100030
# 3        2129279  Collin_County_combined_parcel_100049
# 4        1262715  Collin_County_combined_parcel_100067
# ...          ...                                   ...
# 345345  781626.0     Wise_County_combined_parcel_48085
# 345346  746915.0       Wise_County_combined_parcel_647
# 345347  753228.0      Wise_County_combined_parcel_7455
# 345348  790473.0      Wise_County_combined_parcel_8586
# 345349  783634.0      Wise_County_combined_parcel_9195
#
#                    Parcel_label   lot_width   lot_depth  lot_area  zoning_id  \
# 0         regular inside parcel   49.798850  140.149905  0.160223       1318
# 1       special parcel_standard   92.356753  155.462562  0.330331       1462
# 2         regular inside parcel   75.976481  153.355275  0.257746       1318
# 3         regular inside parcel   88.756216  120.637375  0.244816       1451
# 4         regular corner parcel   72.942981  115.924629  0.194107        412
# ...                         ...         ...         ...       ...        ...
# 345345    regular corner parcel   99.861634   69.713292  0.159818        168
# 345346    regular corner parcel  334.613968  259.647001  1.991946        168
# 345347    regular inside parcel  218.694540  100.216355  0.433263        273
# 345348    regular corner parcel  771.376098  938.497464  5.223278         71
# 345349  special parcel_standard  273.157571  178.421926  0.973641        169
#
#                confidence  check_land_use check_height  ...  \
# 0       confidence_parcel           False          NaN  ...
# 1       confidence_parcel           False          NaN  ...
# 2       confidence_parcel           False          NaN  ...
# 3       confidence_parcel           False          NaN  ...
# 4       confidence_parcel           False          NaN  ...
# ...                   ...             ...          ...  ...
# 345345  confidence_parcel            True         True  ...
# 345346  confidence_parcel            True         True  ...
# 345347  confidence_parcel            True         True  ...
# 345348  confidence_parcel            True         True  ...
# 345349  confidence_parcel            True         True  ...
#
#        check_unit_density check_lot_coverage check_fl_area check_unit_qty  \
# 0                     NaN                NaN           NaN            NaN
# 1                     NaN                NaN           NaN            NaN
# 2                     NaN                NaN           NaN            NaN
# 3                     NaN                NaN           NaN            NaN
# 4                     NaN                NaN           NaN            NaN
# ...                   ...                ...           ...            ...
# 345345               True               True          True           True
# 345346               True               True          True           True
# 345347               True               True          True           True
# 345348               True               True          True           True
# 345349               True               True          True           True
#
#        has_false has_maybe allowed                             reason  \
# 0              1         0   False  FALSE encountered: check_land_use
# 1              1         0   False  FALSE encountered: check_land_use
# 2              1         0   False  FALSE encountered: check_land_use
# 3              1         0   False  FALSE encountered: check_land_use
# 4              1         0   False  FALSE encountered: check_land_use
# ...          ...       ...     ...                                ...
# 345345         0         0    True           parcels fit the building
# 345346         0         0    True           parcels fit the building
# 345347         0         0    True           parcels fit the building
# 345348         0         0    True           parcels fit the building
# 345349         0         0    True           parcels fit the building
#
#         check_footprint                         geometry
# 0                   NaN  POINT (1304352.385 1227377.002)
# 1                   NaN  POINT (1301782.829 1235316.501)
# 2                   NaN  POINT (1304719.267 1229367.106)
# 3                   NaN  POINT (1298876.961 1232769.797)
# 4                   NaN  POINT (1300524.041 1205829.726)
# ...                 ...                              ...
# 345345             True  POINT (1208823.978 1228219.939)
# 345346             True  POINT (1208451.850 1229796.569)
# 345347             True  POINT (1204553.755 1237961.482)
# 345348             True  POINT (1234189.059 1210485.729)
# 345349             True  POINT (1207571.286 1229305.872)
#
# [345350 rows x 24 columns]

# %%
# tidybuilding_4_famtall_result_25_geo.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 345350 entries, 0 to 345349
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Prop_ID             344845 non-null  object
#  1   parcel_id           345350 non-null  object
#  2   Parcel_label        345350 non-null  object
#  3   lot_width           345350 non-null  float64
#  4   lot_depth           345350 non-null  float64
#  5   lot_area            345350 non-null  float64
#  6   zoning_id           345350 non-null  int64
#  7   confidence          345350 non-null  object
#  8   check_land_use      345350 non-null  bool
#  9   check_height        14068 non-null   object
#  10  check_height_eave   9576 non-null    object
#  11  check_stories       9576 non-null    object
#  12  check_unit_size     9245 non-null    object
#  13  check_far           8740 non-null    object
#  14  check_unit_density  8708 non-null    object
#  15  check_lot_coverage  8120 non-null    object
#  16  check_fl_area       7674 non-null    object
#  17  check_unit_qty      7674 non-null    object
#  18  has_false           345350 non-null  int64
#  19  has_maybe           345350 non-null  int64
#  20  allowed             345350 non-null  object
#  21  reason              345350 non-null  object
#  22  check_footprint     7669 non-null    object
#  23  geometry            345350 non-null  geometry
# dtypes: bool(1), float64(3), geometry(1), int64(3), object(16)
# memory usage: 60.9+ MB

# %%
# tidybuilding_4_famtall_result_25_geo.to_csv(r"/Users/houpuli/Dropbox/ceshi/tidybuilding_4_famtall_result_25_geo.csv", index=False)

# %%
# tidybuilding_4_famtall_result_df = zoning_analysis_pipeline(tidybuilding_4_fam_wide, tidyzoning_feeds, tidyparcel_dim_feeds, tidyparcel_geo_feeds,
#                                                             detailed_check = False,
#                                                             run_check_footprint = True)
# tidybuilding_4_famtall_result_df
# Out:
# check_land_use: 101861 / 1953251 parcels allowed (5.2%)
# check_land_use runtime: 0.0 sec
# Running check_height: 100%|██████████| 101861/101861 [2:53:40<00:00,  9.77it/s]
# check_height          Survive: 101861/101861 (100.0%)True: 74699 ( 73.3%)MAYBE: 2583 (  2.5%)False: 24579 ( 24.1%)
# check_height runtime: 10420.7 sec
# Running check_height_eave: 100%|██████████| 77282/77282 [2:10:06<00:00,  9.90it/s]
# check_height_eave     Survive: 77282/101861 ( 75.9%)True: 77193 ( 75.8%)MAYBE:   89 (  0.1%)False:    0 (  0.0%)
# check_height_eave runtime: 7806.8 sec
# Running check_stories: 100%|██████████| 77282/77282 [01:48<00:00, 715.01it/s]
# check_stories         Survive: 77282/101861 ( 75.9%)True: 72771 ( 71.4%)MAYBE:  918 (  0.9%)False: 3593 (  3.5%)
# check_stories runtime: 108.1 sec
# Running check_unit_size: 100%|██████████| 73689/73689 [03:43<00:00, 330.16it/s]
# check_unit_size       Survive: 73689/101861 ( 72.3%)True: 71632 ( 70.3%)MAYBE:  102 (  0.1%)False: 1955 (  1.9%)
# check_unit_size runtime: 223.2 sec
# Running check_far: 100%|██████████| 71734/71734 [2:01:06<00:00,  9.87it/s]
# check_far             Survive: 71734/101861 ( 70.4%)True: 71509 ( 70.2%)MAYBE:   89 (  0.1%)False:  136 (  0.1%)
# check_far runtime: 7266.9 sec
# Running check_unit_density: 100%|██████████| 71598/71598 [01:39<00:00, 722.50it/s]
# check_unit_density    Survive: 71598/101861 ( 70.3%)True: 66728 ( 65.5%)MAYBE:  105 (  0.1%)False: 4765 (  4.7%)
# check_unit_density runtime: 99.1 sec
# Running check_lot_coverage: 100%|██████████| 66833/66833 [1:52:28<00:00,  9.90it/s]
# check_lot_coverage    Survive: 66833/101861 ( 65.6%)True: 62904 ( 61.8%)MAYBE:  104 (  0.1%)False: 3825 (  3.8%)
# check_lot_coverage runtime: 6749.0 sec
# Running check_fl_area: 100%|██████████| 63008/63008 [1:46:09<00:00,  9.89it/s]
# check_fl_area         Survive: 63008/101861 ( 61.9%)True: 62919 ( 61.8%)MAYBE:   89 (  0.1%)False:    0 (  0.0%)
# check_fl_area runtime: 6369.6 sec
# Running check_unit_qty: 100%|██████████| 63008/63008 [1:46:40<00:00,  9.84it/s]
# check_unit_qty        Survive: 63008/101861 ( 61.9%)True: 62877 ( 61.7%)MAYBE:   89 (  0.1%)False:   42 (  0.0%)
# check_unit_qty runtime: 6400.9 sec
# Running check_footprint on 45236/101861 parcels
# check_footprint: 100%|██████████| 45236/45236 [4:53:30<00:00,  2.57it/s]
# check_footprint       Survive: 37740/101861 ( 37.1%)  True: 37209 ( 36.5%)  MAYBE:  531 (  0.5%)  False: 7496 (  7.4%)
# check_footprint runtime: 17610.5 sec
# zoning_analysis_pipeline total runtime: 63078.8 sec
# 36863 / 1953251 parcels fit the building
# 18607 / 1953251 parcels maybe fit the building
#           prop_ID                             parcel_id  \
# 0         2577028       Collin_County_combined_parcel_1
# 1         2593811      Collin_County_combined_parcel_10
# 2         1755568    Collin_County_combined_parcel_1000
# 3         2747493   Collin_County_combined_parcel_10000
# 4         1827401  Collin_County_combined_parcel_100000
# ...           ...                                   ...
# 1953246  754624.0      Wise_County_combined_parcel_9374
# 1953247  770698.0      Wise_County_combined_parcel_9383
# 1953248  733937.0      Wise_County_combined_parcel_9450
# 1953249  732684.0      Wise_County_combined_parcel_9591
# 1953250  787975.0      Wise_County_combined_parcel_9614
#
#                   parcel_label   lot_width   lot_depth  lot_area  zoning_id  \
# 0        regular inside parcel   58.298893  110.904141  0.133264         12
# 1        regular inside parcel   68.062373  125.157973  0.190673        489
# 2        regular inside parcel   84.851943  139.290933  0.228002        349
# 3        regular inside parcel   49.798850  140.149905  0.160223       2150
# 4        regular inside parcel   45.696737   95.492286  0.098509        172
# ...                        ...         ...         ...       ...        ...
# 1953246   special parcel_other    1.000000    1.000000  0.060597       1665
# 1953247  regular corner parcel  125.411803  120.021121  0.344533       2090
# 1953248  regular corner parcel  105.567961   57.520230  0.135661       1665
# 1953249     duplicated address    1.000000    1.000000  1.049195        834
# 1953250  regular corner parcel  422.408321  415.135370  3.930124        834
#
#                     confidence  check_land_use check_height  ... check_far  \
# 0            confidence_parcel           False          NaN  ...       NaN
# 1            confidence_parcel           False          NaN  ...       NaN
# 2            confidence_parcel           False          NaN  ...       NaN
# 3            confidence_parcel           False          NaN  ...       NaN
# 4            confidence_parcel           False          NaN  ...       NaN
# ...                        ...             ...          ...  ...       ...
# 1953246  non_confidence_parcel            True         True  ...      True
# 1953247      confidence_parcel            True         True  ...      True
# 1953248      confidence_parcel            True         True  ...      True
# 1953249  non_confidence_parcel            True         True  ...      True
# 1953250      confidence_parcel            True         True  ...      True
#
#         check_unit_density check_lot_coverage check_fl_area check_unit_qty  \
# 0                      NaN                NaN           NaN            NaN
# 1                      NaN                NaN           NaN            NaN
# 2                      NaN                NaN           NaN            NaN
# 3                      NaN                NaN           NaN            NaN
# 4                      NaN                NaN           NaN            NaN
# ...                    ...                ...           ...            ...
# 1953246               True               True          True           True
# 1953247               True               True          True           True
# 1953248               True               True          True           True
# 1953249               True               True          True           True
# 1953250               True               True          True           True
#
#         has_false has_maybe allowed  \
# 0               1         0   False
# 1               1         0   False
# 2               1         0   False
# 3               1         0   False
# 4               1         0   False
# ...           ...       ...     ...
# 1953246         0         0   MAYBE
# 1953247         0         1   MAYBE
# 1953248         0         0   False
# 1953249         0         0   MAYBE
# 1953250         0         0    True
#
#                                                     reason  check_footprint
# 0                        FALSE encountered: check_land_use              NaN
# 1                        FALSE encountered: check_land_use              NaN
# 2                        FALSE encountered: check_land_use              NaN
# 3                        FALSE encountered: check_land_use              NaN
# 4                        FALSE encountered: check_land_use              NaN
# ...                                                    ...              ...
# 1953246       Initial check passed, but no footprint check              NaN
# 1953247  MAYBE encountered: check_stories, check_footprint            MAYBE
# 1953248                 FALSE encountered: check_footprint            False
# 1953249       Initial check passed, but no footprint check              NaN
# 1953250                           parcels fit the building             True
#
# [1953251 rows x 23 columns]

# %%
# # Merge the output cvs DataFrame with the geometry from tidyparcel_geo_feeds
# tidybuilding_4_famtall_result_df_geo = tidybuilding_4_famtall_result_df.merge(tidyparcel_geo_feeds[tidyparcel_geo_feeds['side'] == 'centroid'][['parcel_id', 'geometry']], on='parcel_id', how='left')

# # Convert the merged DataFrame into a GeoDataFrame
# tidybuilding_4_famtall_result_df_geo = gpd.GeoDataFrame(tidybuilding_4_famtall_result_df_geo, geometry='geometry', crs=tidyparcel_geo_feeds.crs)
# tidybuilding_4_famtall_result_df_geo
# Out:
#           prop_ID                             parcel_id  \
# 0         2577028       Collin_County_combined_parcel_1
# 1         2593811      Collin_County_combined_parcel_10
# 2         1755568    Collin_County_combined_parcel_1000
# 3         2747493   Collin_County_combined_parcel_10000
# 4         1827401  Collin_County_combined_parcel_100000
# ...           ...                                   ...
# 1953246  754624.0      Wise_County_combined_parcel_9374
# 1953247  770698.0      Wise_County_combined_parcel_9383
# 1953248  733937.0      Wise_County_combined_parcel_9450
# 1953249  732684.0      Wise_County_combined_parcel_9591
# 1953250  787975.0      Wise_County_combined_parcel_9614
#
#                   parcel_label   lot_width   lot_depth  lot_area  zoning_id  \
# 0        regular inside parcel   58.298893  110.904141  0.133264         12
# 1        regular inside parcel   68.062373  125.157973  0.190673        489
# 2        regular inside parcel   84.851943  139.290933  0.228002        349
# 3        regular inside parcel   49.798850  140.149905  0.160223       2150
# 4        regular inside parcel   45.696737   95.492286  0.098509        172
# ...                        ...         ...         ...       ...        ...
# 1953246   special parcel_other    1.000000    1.000000  0.060597       1665
# 1953247  regular corner parcel  125.411803  120.021121  0.344533       2090
# 1953248  regular corner parcel  105.567961   57.520230  0.135661       1665
# 1953249     duplicated address    1.000000    1.000000  1.049195        834
# 1953250  regular corner parcel  422.408321  415.135370  3.930124        834
#
#                     confidence  check_land_use check_height  ...  \
# 0            confidence_parcel           False          NaN  ...
# 1            confidence_parcel           False          NaN  ...
# 2            confidence_parcel           False          NaN  ...
# 3            confidence_parcel           False          NaN  ...
# 4            confidence_parcel           False          NaN  ...
# ...                        ...             ...          ...  ...
# 1953246  non_confidence_parcel            True         True  ...
# 1953247      confidence_parcel            True         True  ...
# 1953248      confidence_parcel            True         True  ...
# 1953249  non_confidence_parcel            True         True  ...
# 1953250      confidence_parcel            True         True  ...
#
#         check_unit_density check_lot_coverage check_fl_area check_unit_qty  \
# 0                      NaN                NaN           NaN            NaN
# 1                      NaN                NaN           NaN            NaN
# 2                      NaN                NaN           NaN            NaN
# 3                      NaN                NaN           NaN            NaN
# 4                      NaN                NaN           NaN            NaN
# ...                    ...                ...           ...            ...
# 1953246               True               True          True           True
# 1953247               True               True          True           True
# 1953248               True               True          True           True
# 1953249               True               True          True           True
# 1953250               True               True          True           True
#
#         has_false has_maybe allowed  \
# 0               1         0   False
# 1               1         0   False
# 2               1         0   False
# 3               1         0   False
# 4               1         0   False
# ...           ...       ...     ...
# 1953246         0         0   MAYBE
# 1953247         0         1   MAYBE
# 1953248         0         0   False
# 1953249         0         0   MAYBE
# 1953250         0         0    True
#
#                                                     reason  check_footprint  \
# 0                        FALSE encountered: check_land_use              NaN
# 1                        FALSE encountered: check_land_use              NaN
# 2                        FALSE encountered: check_land_use              NaN
# 3                        FALSE encountered: check_land_use              NaN
# 4                        FALSE encountered: check_land_use              NaN
# ...                                                    ...              ...
# 1953246       Initial check passed, but no footprint check              NaN
# 1953247  MAYBE encountered: check_stories, check_footprint            MAYBE
# 1953248                 FALSE encountered: check_footprint            False
# 1953249       Initial check passed, but no footprint check              NaN
# 1953250                           parcels fit the building             True
#
#                                 geometry
# 0        POINT (1322569.833 1229621.524)
# 1        POINT (1298633.220 1227254.211)
# 2        POINT (1304981.109 1215980.212)
# 3        POINT (1304352.385 1227377.002)
# 4        POINT (1298793.461 1207578.341)
# ...                                  ...
# 1953246  POINT (1208255.855 1228277.121)
# 1953247  POINT (1215487.467 1221620.259)
# 1953248  POINT (1209110.801 1227635.442)
# 1953249  POINT (1223809.623 1230025.664)
# 1953250  POINT (1225343.205 1228729.176)
#
# [1953251 rows x 24 columns]

# %%
# tidybuilding_4_famtall_result_df_geo.to_csv(r"/Users/houpuli/Dropbox/ceshi/tidybuilding_4_famtall_result_df_geo.csv", index=False)

# %% [markdown]
# <!-- ### Debugging the process -->

# %%
# kamryn_results = pd.read_csv(r"/Users/houpuli/Dropbox/ceshi/all_checks_25_pct_lu_TRUE.csv")
# kamryn_results['zoning_id'] = kamryn_results['zoning_id'] - 1
# kamryn_results
# Out:
#        Unnamed: 0  Prop_ID                             parcel_id  \
# 0        1.240000  1140143  Collin_County_combined_parcel_100303
# 1        1.540000  2712455   Collin_County_combined_parcel_10067
# 2        1.570000  2529683  Collin_County_combined_parcel_100752
# 3        1.134000  1105725  Collin_County_combined_parcel_101602
# 4        1.208000  2529792  Collin_County_combined_parcel_102471
# ...           ...      ...                                   ...
# 14063    7.345223   781626     Wise_County_combined_parcel_48085
# 14064    7.345287   746915       Wise_County_combined_parcel_647
# 14065    7.345313   753228      Wise_County_combined_parcel_7455
# 14066    7.345331   790473      Wise_County_combined_parcel_8586
# 14067    7.345347   783634      Wise_County_combined_parcel_9195
#
#                   Parcel_label   lot_width    lot_depth  lot_area  zoning_id  \
# 0        regular inside parcel   60.377629    57.094367  0.078207       1319
# 1        regular inside parcel   48.491800   119.395533  0.132909       1319
# 2      special parcel_standard   43.442223   131.532296  0.127566       1761
# 3        regular inside parcel  129.624525   141.769853  0.416691       1319
# 4        regular inside parcel   44.287817   137.043459  0.134441       1761
# ...                        ...         ...          ...       ...        ...
# 14063    regular corner parcel  119.416309    83.757465  0.229614        168
# 14064    regular corner parcel  400.201694   312.001538  2.862745        168
# 14065    regular inside parcel  261.767899   120.502010  0.623661        273
# 14066    regular corner parcel  920.796514  1122.352092  7.477974         71
# 14067  special parcel_standard  326.682317   214.367352  1.399150        169
#
#        check_land_use check_height  check_height_eave check_floors  \
# 0                True         TRUE               True         TRUE
# 1                True         TRUE               True         TRUE
# 2                True         TRUE               True         TRUE
# 3                True         TRUE               True         TRUE
# 4                True         TRUE               True         TRUE
# ...               ...          ...                ...          ...
# 14063            True         TRUE               True         TRUE
# 14064            True         TRUE               True         TRUE
# 14065            True         TRUE               True         TRUE
# 14066            True         TRUE               True         TRUE
# 14067            True         TRUE               True         TRUE
#
#       check_unit_size  check_far check_unit_density check_lot_coverage  \
# 0                TRUE       True               TRUE               TRUE
# 1                TRUE       True               TRUE               TRUE
# 2               FALSE       True              FALSE               TRUE
# 3                TRUE       True               TRUE               TRUE
# 4               FALSE       True              FALSE               TRUE
# ...               ...        ...                ...                ...
# 14063            TRUE       True               TRUE               TRUE
# 14064            TRUE       True               TRUE               TRUE
# 14065            TRUE       True               TRUE               TRUE
# 14066            TRUE       True               TRUE               TRUE
# 14067            TRUE       True               TRUE               TRUE
#
#        check_fl_area  check_unit_qty
# 0               True            True
# 1               True            True
# 2               True            True
# 3               True            True
# 4               True            True
# ...              ...             ...
# 14063           True            True
# 14064           True            True
# 14065           True            True
# 14066           True            True
# 14067           True            True
#
# [14068 rows x 18 columns]

# %%
# cols = [
#     'check_land_use', 'check_height', 'check_height_eave', 'check_floors',
#     'check_unit_size', 'check_far', 'check_unit_density', 'check_lot_coverage',
#     'check_fl_area', 'check_unit_qty'
# ]
# kamryn_results[cols] = kamryn_results[cols].applymap(lambda x: str(x).upper())
# statistic_results = pd.DataFrame(index=["TRUE", "FALSE", "MAYBE"])

# for col in cols:
#     count_series = kamryn_results[col].value_counts()
#     statistic_results[col] = count_series

# statistic_results = statistic_results.fillna(0).astype(int)
# statistic_results = statistic_results.transpose()
# statistic_results
# Out:
# /var/folders/s5/1g0kvw1x37z1n8xgxcp8f3lh0000gn/T/ipykernel_1298/1597969407.py:6: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   kamryn_results[cols] = kamryn_results[cols].applymap(lambda x: str(x).upper())
#                      TRUE  FALSE  MAYBE
# check_land_use      14068      0      0
# check_height         9249   4492    327
# check_height_eave   14068      0      0
# check_floors        13113    805    150
# check_unit_size     13442    623      3
# check_far           13869    199      0
# check_unit_density  12240   1824      4
# check_lot_coverage  13012   1049      7
# check_fl_area       14068      0      0
# check_unit_qty      14062      6      0

# %%
# cols = [
#     'check_land_use', 'check_height', 'check_height_eave', 'check_floors',
#     'check_unit_size', 'check_far', 'check_unit_density',
#     'check_lot_coverage', 'check_fl_area', 'check_unit_qty'
# ]

# # create a boolean DataFrame marking True wherever the cell is True (or the string 'True')
# checks_bool = kamryn_results[cols].applymap(lambda x: x is True or x == 'TRUE')

# # count how many rows have every column True
# count_all_true = checks_bool.all(axis=1).sum()

# print(f"{count_all_true} rows have all {len(cols)} checks == TRUE")
# Out:
# 7712 rows have all 10 checks == TRUE
# /var/folders/s5/1g0kvw1x37z1n8xgxcp8f3lh0000gn/T/ipykernel_1298/644753729.py:8: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   checks_bool = kamryn_results[cols].applymap(lambda x: x is True or x == 'TRUE')

# %%
# compare_id_differences(check_lot_coverage_result_all, kamryn_results, kamryn_filter_col='check_lot_coverage')
# Out:
# Only in the first dataset for zoning_id: set()
# Only in kamryn_results for zoning_id: set()
# Only in the first dataset for parcel_id: set()
# Only in kamryn_results for parcel_id: set()

# %%
# draft_check = zoning_analysis_pipeline(tidybuilding_4_fam_wide, tidyzoning_3857, tidyparcel_3857, confident_tidyparcel_3857, n_jobs=12, debug=True)
# draft_check
# Out:
# Parcel count: total 345350 parcels,
# 14068 passed land use check; others marked as check_land_use=False.
# Percentage remaining: 4.07%.
# Processing Allowed Parcels: 100%|██████████| 14068/14068 [11:50<00:00, 19.80it/s]
#          Prop_ID                             parcel_id  zoning_id allowed  \
# 14068    2747493   Collin_County_combined_parcel_10000       1318   False
# 14069    2702267  Collin_County_combined_parcel_100028       1462   False
# 14070    2082442  Collin_County_combined_parcel_100030       1318   False
# 14071    2129279  Collin_County_combined_parcel_100049       1451   False
# 14072    1262715  Collin_County_combined_parcel_100067        412   False
# ...          ...                                   ...        ...     ...
# 345346  783763.0      Wise_County_combined_parcel_9058         66   False
# 14067   783634.0      Wise_County_combined_parcel_9195        169    True
# 345347  755021.0      Wise_County_combined_parcel_9452        171   False
# 345348  753256.0      Wise_County_combined_parcel_9590        270   False
# 345349  768605.0      Wise_County_combined_parcel_9946         22   False
#
#                              reason  \
# 14068                check_land_use
# 14069                check_land_use
# 14070                check_land_use
# 14071                check_land_use
# 14072                check_land_use
# ...                             ...
# 345346               check_land_use
# 14067   Our tidybuilding is allowed
# 345347               check_land_use
# 345348               check_land_use
# 345349               check_land_use
#
#                                             check_process
# 14068                           {'check_land_use': False}
# 14069                           {'check_land_use': False}
# 14070                           {'check_land_use': False}
# 14071                           {'check_land_use': False}
# 14072                           {'check_land_use': False}
# ...                                                   ...
# 345346                          {'check_land_use': False}
# 14067   {'check_land_use': True, 'check_height': True,...
# 345347                          {'check_land_use': False}
# 345348                          {'check_land_use': False}
# 345349                          {'check_land_use': False}
#
# [345350 rows x 6 columns]

# %%
# initial_check = draft_check[draft_check['allowed'] == True]
# initial_check
# Out:
#         Prop_ID                             parcel_id  zoning_id allowed  \
# 0       1140143  Collin_County_combined_parcel_100303       1319    True
# 1       2712455   Collin_County_combined_parcel_10067       1319    True
# 3       1105725  Collin_County_combined_parcel_101602       1319    True
# 7       1326443  Collin_County_combined_parcel_104198       1319    True
# 8       2107181  Collin_County_combined_parcel_104734       1319    True
# ...         ...                                   ...        ...     ...
# 14063  781626.0     Wise_County_combined_parcel_48085        168    True
# 14064  746915.0       Wise_County_combined_parcel_647        168    True
# 14065  753228.0      Wise_County_combined_parcel_7455        273    True
# 14066  790473.0      Wise_County_combined_parcel_8586         71    True
# 14067  783634.0      Wise_County_combined_parcel_9195        169    True
#
#                             reason  \
# 0      Our tidybuilding is allowed
# 1      Our tidybuilding is allowed
# 3      Our tidybuilding is allowed
# 7      Our tidybuilding is allowed
# 8      Our tidybuilding is allowed
# ...                            ...
# 14063  Our tidybuilding is allowed
# 14064  Our tidybuilding is allowed
# 14065  Our tidybuilding is allowed
# 14066  Our tidybuilding is allowed
# 14067  Our tidybuilding is allowed
#
#                                            check_process
# 0      {'check_land_use': True, 'check_height': True,...
# 1      {'check_land_use': True, 'check_height': True,...
# 3      {'check_land_use': True, 'check_height': True,...
# 7      {'check_land_use': True, 'check_height': True,...
# 8      {'check_land_use': True, 'check_height': True,...
# ...                                                  ...
# 14063  {'check_land_use': True, 'check_height': True,...
# 14064  {'check_land_use': True, 'check_height': True,...
# 14065  {'check_land_use': True, 'check_height': True,...
# 14066  {'check_land_use': True, 'check_height': True,...
# 14067  {'check_land_use': True, 'check_height': True,...
#
# [7712 rows x 6 columns]

# %%
# kamryn_final_result2 = pd.read_csv(r'/Users/houpuli/Dropbox/ceshi/check_footprint_25_pct.csv')
# kamryn_final_result2['zoning_id'] = kamryn_final_result2['zoning_id'] -1
# kamryn_final_result2
# Out:
#       Prop_ID                             parcel_id             Parcel_label  \
# 0     1140143  Collin_County_combined_parcel_100303    regular inside parcel
# 1     2712455   Collin_County_combined_parcel_10067    regular inside parcel
# 2     1105725  Collin_County_combined_parcel_101602    regular inside parcel
# 3     1326443  Collin_County_combined_parcel_104198    regular corner parcel
# 4     2107181  Collin_County_combined_parcel_104734    regular corner parcel
# ...       ...                                   ...                      ...
# 7588   781626     Wise_County_combined_parcel_48085    regular corner parcel
# 7589   746915       Wise_County_combined_parcel_647    regular corner parcel
# 7590   753228      Wise_County_combined_parcel_7455    regular inside parcel
# 7591   790473      Wise_County_combined_parcel_8586    regular corner parcel
# 7592   783634      Wise_County_combined_parcel_9195  special parcel_standard
#
#        lot_width    lot_depth  lot_area  zoning_id  check_land_use  \
# 0      60.377629    57.094367  0.078207       1319            True
# 1      48.491800   119.395533  0.132909       1319            True
# 2     129.624525   141.769853  0.416691       1319            True
# 3      78.757869   141.739173  0.256268       1319            True
# 4     125.414149   152.311911  0.437292       1319            True
# ...          ...          ...       ...        ...             ...
# 7588  119.416309    83.757465  0.229614        168            True
# 7589  400.201694   312.001538  2.862745        168            True
# 7590  261.767899   120.502010  0.623661        273            True
# 7591  920.796514  1122.352092  7.477974         71            True
# 7592  326.682317   214.367352  1.399150        169            True
#
#       check_height  check_height_eave  check_floors  check_unit_size  \
# 0             True               True          True             True
# 1             True               True          True             True
# 2             True               True          True             True
# 3             True               True          True             True
# 4             True               True          True             True
# ...            ...                ...           ...              ...
# 7588          True               True          True             True
# 7589          True               True          True             True
# 7590          True               True          True             True
# 7591          True               True          True             True
# 7592          True               True          True             True
#
#       check_far  check_unit_density  check_lot_coverage  check_fl_area  \
# 0          True                True                True           True
# 1          True                True                True           True
# 2          True                True                True           True
# 3          True                True                True           True
# 4          True                True                True           True
# ...         ...                 ...                 ...            ...
# 7588       True                True                True           True
# 7589       True                True                True           True
# 7590       True                True                True           True
# 7591       True                True                True           True
# 7592       True                True                True           True
#
#       bldg_area  check_footprint_area check_footprint
# 0          2496                  True            TRUE
# 1          2496                  True            TRUE
# 2          2496                  True            TRUE
# 3          2496                  True            TRUE
# 4          2496                  True            TRUE
# ...         ...                   ...             ...
# 7588       2496                  True           FALSE
# 7589       2496                  True            TRUE
# 7590       2496                  True            TRUE
# 7591       2496                  True            TRUE
# 7592       2496                  True            TRUE
#
# [7593 rows x 19 columns]

# %%
# import pandas as pd

# def compare_id_differences_initial(df_houpu, df_kamryn, kamryn_filter_col='check_far'):
#     """
#     Compare the differences in 'zoning_id' and 'parcel_id' between two datasets that meet specific conditions,
#     and directly print the results.

#     Parameters:
#       df_houpu: The first dataset, which contains the fields 'allowed', 'zoning_id', and 'parcel_id'.
#       df_kamryn: The second dataset, which contains the filtering field (default is 'check_far'), 
#                  'zoning_id', and 'parcel_id'.
#       kamryn_filter_col: The name of the field used for filtering df_kamryn. Default value is 'check_far'.

#     Processing logic:
#       - Filter df_houpu: retain records where 'allowed' is False or 'MAYBE'.
#       - Filter df_kamryn: retain records where the filtering field (kamryn_filter_col) is False or 'MAYBE'.
#       - Compare the filtered 'zoning_id' and 'parcel_id' values by computing the differences.
#       - Print the results as follows:
#             "Only in the first dataset for <field>: set(...)"
#             "Only in kamryn_results for <field>: set(...)"

#     Example:
#       compare_id_differences(check_far_result_all, kamryn_results, kamryn_filter_col='check_far')
#     """
#     # Define the fields to compare: only 'zoning_id' and 'parcel_id'
#     compare_cols = ['zoning_id', 'parcel_id']
    
#     # # Filter df_houpu: retain records where 'allowed' is False or 'MAYBE'
#     # filtered_all = df_houpu[(df_houpu['allowed'] == False) | (df_houpu['allowed'] == 'MAYBE')]
#     # # Filter df_kamryn: retain records where the filtering field is False or 'MAYBE'
#     # filtered_kamryn = df_kamryn[(df_kamryn[kamryn_filter_col] == 'FALSE') | (df_kamryn[kamryn_filter_col] == 'MAYBE')]
    
#     # Loop over the fields to compare, calculate and print the differences
#     for col in compare_cols:
#         set_all = set(df_houpu[col])
#         set_kamryn = set(df_kamryn[col])
        
#         only_in_all = set_all - set_kamryn
#         only_in_kamryn = set_kamryn - set_all
        
#         print("Only in the first dataset for {}: {≠}".format(col, only_in_all))
#         print("Only in kamryn_results for {}: {}".format(col, only_in_kamryn))
        
# compare_id_differences_initial(initial_check, kamryn_final_result2, kamryn_filter_col='check_lot_coverage')
# Out:
# Only in the first dataset for zoning_id: set()
# Only in kamryn_results for zoning_id: {941}
# Only in the first dataset for parcel_id: {'Denton_County_combined_parcel_311768', 'Tarrant_County_combined_parcel_386329', 'Dallas_County_combined_parcel_661982', 'Tarrant_County_combined_parcel_326417', 'Dallas_County_combined_parcel_578322', 'Tarrant_County_combined_parcel_135885', 'Tarrant_County_combined_parcel_542675', 'Hood_County_combined_parcel_15848', 'Tarrant_County_combined_parcel_328163', 'Tarrant_County_combined_parcel_1133669', 'Denton_County_combined_parcel_210486', 'Denton_County_combined_parcel_196689', 'Tarrant_County_combined_parcel_1953654', 'Denton_County_combined_parcel_210012', 'Denton_County_combined_parcel_272991', 'Tarrant_County_combined_parcel_135849', 'Denton_County_combined_parcel_181217', 'Denton_County_combined_parcel_198715', 'Tarrant_County_combined_parcel_571313', 'Tarrant_County_combined_parcel_386312', 'Dallas_County_combined_parcel_602737', 'Ellis_County_combined_parcel_94611', 'Ellis_County_combined_parcel_59213', 'Denton_County_combined_parcel_197659', 'Denton_County_combined_parcel_168453', 'Ellis_County_combined_parcel_91229', 'Tarrant_County_combined_parcel_33788', 'Denton_County_combined_parcel_183545', 'Tarrant_County_combined_parcel_915565', 'Tarrant_County_combined_parcel_386316', 'Denton_County_combined_parcel_297944', 'Dallas_County_combined_parcel_90444', 'Ellis_County_combined_parcel_90620', 'Dallas_County_combined_parcel_59581', 'Hood_County_combined_parcel_13860', 'Tarrant_County_combined_parcel_505232', 'Ellis_County_combined_parcel_95399', 'Tarrant_County_combined_parcel_386306', 'Tarrant_County_combined_parcel_326412', 'Denton_County_combined_parcel_284293', 'Tarrant_County_combined_parcel_135867', 'Tarrant_County_combined_parcel_571315', 'Tarrant_County_combined_parcel_135889', 'Tarrant_County_combined_parcel_599766', 'Denton_County_combined_parcel_207928', 'Tarrant_County_combined_parcel_326463', 'Tarrant_County_combined_parcel_135877', 'Tarrant_County_combined_parcel_51862', 'Dallas_County_combined_parcel_48833', 'Tarrant_County_combined_parcel_135308', 'Denton_County_combined_parcel_339414', 'Tarrant_County_combined_parcel_135882', 'Denton_County_combined_parcel_181505', 'Dallas_County_combined_parcel_683247', 'Tarrant_County_combined_parcel_135860', 'Denton_County_combined_parcel_231643', 'Denton_County_combined_parcel_234997', 'Collin_County_combined_parcel_163191', 'Tarrant_County_combined_parcel_607941', 'Collin_County_combined_parcel_123646', 'Tarrant_County_combined_parcel_1549149', 'Tarrant_County_combined_parcel_327391', 'Denton_County_combined_parcel_230241', 'Denton_County_combined_parcel_207927', 'Denton_County_combined_parcel_334754', 'Ellis_County_combined_parcel_59084', 'Tarrant_County_combined_parcel_1549151', 'Tarrant_County_combined_parcel_2044647', 'Tarrant_County_combined_parcel_538420', 'Tarrant_County_combined_parcel_36717', 'Denton_County_combined_parcel_227595', 'Ellis_County_combined_parcel_71310', 'Tarrant_County_combined_parcel_135312', 'Tarrant_County_combined_parcel_135886', 'Dallas_County_combined_parcel_48034', 'Dallas_County_combined_parcel_72545', 'Tarrant_County_combined_parcel_135321', 'Tarrant_County_combined_parcel_1133699', 'Dallas_County_combined_parcel_48044', 'Tarrant_County_combined_parcel_286256', 'Denton_County_combined_parcel_310423', 'Tarrant_County_combined_parcel_391454', 'Denton_County_combined_parcel_207929', 'Denton_County_combined_parcel_182262', 'Tarrant_County_combined_parcel_326454', 'Ellis_County_combined_parcel_30493', 'Denton_County_combined_parcel_309230', 'Denton_County_combined_parcel_210487', 'Dallas_County_combined_parcel_48030', 'Denton_County_combined_parcel_306785', 'Denton_County_combined_parcel_209017', 'Tarrant_County_combined_parcel_2839996', 'Denton_County_combined_parcel_231498', 'Denton_County_combined_parcel_232600', 'Dallas_County_combined_parcel_48037', 'Collin_County_combined_parcel_5263', 'Denton_County_combined_parcel_167672', 'Tarrant_County_combined_parcel_62689', 'Denton_County_combined_p ...
# Only in kamryn_results for parcel_id: {'Tarrant_County_combined_parcel_55651', 'Tarrant_County_combined_parcel_383610', 'Tarrant_County_combined_parcel_383393', 'Tarrant_County_combined_parcel_384246', 'Tarrant_County_combined_parcel_383395', 'Tarrant_County_combined_parcel_30790'}

# %%
# draft_check[draft_check['parcel_id'] == 'Denton_County_combined_parcel_311768']
# Out:
#      Prop_ID                             parcel_id  zoning_id allowed  \
# 5288  744052  Denton_County_combined_parcel_311768       1256    True
#
#                            reason  \
# 5288  Our tidybuilding is allowed
#
#                                           check_process
# 5288  {'check_land_use': True, 'check_height': True,...

# %%
# tidyzoning_3857.loc[1256]['structure_constraints']
# Out:
# {'setback_front': [{'unit': 'feet',
#    'use_name': ['1_family', '3_family', '4_family', 'Townhome'],
#    'min_val': [{'conditions': ['height <= 80'],
#      'select': 'max',
#      'select_info': 'NA',
#      'expressions': [0, 0]},
#     {'conditions': ['height > 80'], 'expression': '(height - 80) / 2'}]}],
#  'setback_side_int': [{'unit': 'feet',
#    'use_name': ['1_family', '3_family', '4_family', 'Townhome'],
#    'min_val': [{'conditions': ['height <= 80'],
#      'select': 'max',
#      'select_info': 'NA',
#      'expressions': [0, '0']},
#     {'conditions': ['height > 80'], 'expression': '(height - 80) / 2'}]}],
#  'setback_side_ext': [{'unit': 'feet',
#    'use_name': ['1_family', '3_family', '4_family', 'Townhome'],
#    'min_val': [{'conditions': ['height <= 80'], 'expression': 0},
#     {'conditions': ['height > 80'], 'expression': '(height - 80) / 2'}]}],
#  'setback_rear': [{'unit': 'feet',
#    'use_name': ['1_family', '3_family', '4_family', 'Townhome'],
#    'min_val': [{'conditions': ['height <= 80'],
#      'select': 'max',
#      'select_info': 'NA',
#      'expressions': [0, 0]},
#     {'conditions': ['height > 80'], 'expression': '(height - 80) / 2'}]}],
#  'unit_size': [{'unit': 'square feet',
#    'use_name': 'Townhome',
#    'min_val': {'expression': '1200'}},
#   {'unit': 'square feet',
#    'use_name': '1_family',
#    'min_val': {'expression': '1600'}},
#   {'unit': 'square feet',
#    'use_name': ['3_family', '4_family'],
#    'min_val': {'expression': '500'}}],
#  'unit_size_avg': [{'unit': 'square feet',
#    'use_name': ['3_family', '4_family'],
#    'min_val': {'expression': '650'}}]}

# %%
# kamryn_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14068 entries, 0 to 14067
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          14068 non-null  float64
#  1   Prop_ID             14046 non-null  object
#  2   parcel_id           14068 non-null  object
#  3   Parcel_label        14068 non-null  object
#  4   lot_width           14068 non-null  float64
#  5   lot_depth           14068 non-null  float64
#  6   lot_area            14068 non-null  float64
#  7   zoning_id           14068 non-null  int64
#  8   check_land_use      14068 non-null  object
#  9   check_height        14068 non-null  object
#  10  check_height_eave   14068 non-null  object
#  11  check_floors        14068 non-null  object
#  12  check_unit_size     14068 non-null  object
#  13  check_far           14068 non-null  object
#  14  check_unit_density  14068 non-null  object
#  15  check_lot_coverage  14068 non-null  object
#  16  check_fl_area       14068 non-null  object
#  17  check_unit_qty      14068 non-null  object
# dtypes: float64(4), int64(1), object(13)
# memory usage: 1.9+ MB

# %%
# tidybuilding_4_fam_wide
# Out:
#    stories  height  width  depth  height_eave      type  gross_fl_area  \
# 0        3      38     52     48           28  4_family           4600
#
#    net_fl_area  max_unit_size  min_unit_size  ...  units_3bed_maxsize  \
# 0         4432           1108           1108  ...                1108
#
#    units_floor1  units_floor2  units_floor3  parking_covered  \
# 0             4             0             0                0
#
#    parking_uncovered  parking_enclosed  parking_floors  parking_bel_grade  \
# 0                  0                 4               1                yes
#
#    garage_entry
# 0  [side, rear]
#
# [1 rows x 26 columns]

# %%
# check_bedrooms_result_all = check_zoning_process(tidybuilding_4_fam_wide, tidyzoning, confident_tidyparcel_dim, check_bedrooms, n_jobs=-1)
# check_bedrooms_result_all

# %%
#

# %%
#

# %%
#

# %%
#

# %% [markdown]
# <!-- ### Out the dataset -->

# %%
# import geopandas as gpd

# # 2. Get all unique parcel_id values
# unique_ids = filtered['parcel_id'].unique()
# total_groups = len(unique_ids)
# print(f"There are a total of {total_groups} groups.")

# # Calculate the number of groups each dataset should include
# groups_per_dataset = total_groups // 5

# # 3. Split the data by group and export
# for i in range(5):
#     start_index = i * groups_per_dataset
#     # Ensure that the last dataset includes all remaining groups
#     if i == 4:
#         current_ids = unique_ids[start_index:]
#     else:
#         current_ids = unique_ids[start_index:start_index + groups_per_dataset]
    
#     # Filter out all records for the current part
#     subset_gdf = filtered[filtered['parcel_id'].isin(current_ids)]
    
#     # Generate output filename and export as a GeoJSON file
#     output_filename = f'/Users/houpuli/Dropbox/ceshi/parcel_part{i+1}.geojson'
#     subset_gdf.to_file(output_filename, driver='GeoJSON')
#     print(f"Dataset {i+1} has been exported: it contains {len(current_ids)} groups and a total of {len(subset_gdf)} records.")
# Out:
# There are a total of 1953251 groups.
# Dataset 1 has been exported: it contains 390650 groups and a total of 2141072 records.
# Dataset 2 has been exported: it contains 390650 groups and a total of 2074846 records.
# Dataset 3 has been exported: it contains 390650 groups and a total of 2123248 records.
# Dataset 4 has been exported: it contains 390650 groups and a total of 2092313 records.
# Dataset 5 has been exported: it contains 390651 groups and a total of 2110537 records.

# %%
# import geopandas as gpd

# def reproject_geojson_parcel_edge(input_path, output_path, original_crs=3857, target_crs=4326):
#     """
#     Reads a GeoJSON file, sets its CRS, converts it to another CRS, and saves it.

#     Parameters:
#     -----------
#     input_path : str
#         Path to the input GeoJSON file.
#     output_path : str
#         Path to save the transformed GeoJSON file.
#     original_crs : int, optional
#         EPSG code of the original CRS. Default is 3857.
#     target_crs : int, optional
#         EPSG code of the target CRS. Default is 4326.
#     """
#     gdf = gpd.read_file(input_path)
#     gdf = gdf.set_crs(original_crs, allow_override=True)
#     gdf = gdf.to_crs(target_crs)
#     gdf.to_file(output_path, driver='GeoJSON')
#     return gdf

# input_fp = r"C:\Users\Admin\Desktop\New folder (6)\Output_dataset\Tarrant_County_combined_parcel.geojson"
# output_fp = r"C:\Users\Admin\Desktop\New folder (6)\Output_dataset\Tarrant_County_combined_parcel.geojson"

# gdf_parcel = reproject_geojson_parcel_edge(input_fp, output_fp)
# gdf_parcel
# Out:
#           Prop_ID  GEO_ID parcel_id           parcel_addr landuse  \
# 0        07214383     NaN        10         8141 WENDY LN       R
# 1        07214383     NaN        10         8141 WENDY LN       R
# 2        07214383     NaN        10         8141 WENDY LN       R
# 3        07214383     NaN        10         8141 WENDY LN       R
# 4        07214383     NaN        10         8141 WENDY LN       R
# ...           ...     ...       ...                   ...     ...
# 3685233  06888585     NaN     99999  6616 CANYON CREST DR       R
# 3685234  06888585     NaN     99999  6616 CANYON CREST DR       R
# 3685235  06888585     NaN     99999  6616 CANYON CREST DR       R
# 3685236  06888585     NaN     99999  6616 CANYON CREST DR       R
# 3685237  06888585     NaN     99999  6616 CANYON CREST DR       R
#
#         landuse_spec           parcel_label Found_Match match_road_address  \
# 0                  A  regular inside parcel        True           Wendy Ln
# 1                  A  regular inside parcel        True           Wendy Ln
# 2                  A  regular inside parcel        True           Wendy Ln
# 3                  A  regular inside parcel        True           Wendy Ln
# 4                  A  regular inside parcel        True           Wendy Ln
# ...              ...                    ...         ...                ...
# 3685233            A  regular inside parcel        True    Canyon Crest Dr
# 3685234            A  regular inside parcel        True    Canyon Crest Dr
# 3685235            A  regular inside parcel        True    Canyon Crest Dr
# 3685236            A  regular inside parcel        True    Canyon Crest Dr
# 3685237            A  regular inside parcel        True    Canyon Crest Dr
#
#          shape_index  50_threshold  num_edges  angle_difference  shared_side  \
# 0           1.274299          True          4         10.120739         True
# 1           1.274299          True          4         10.120739         True
# 2           1.274299          True          4         10.120739        False
# 3           1.274299          True          4         10.120739        False
# 4           1.274299          True          4         10.120739        False
# ...              ...           ...        ...               ...          ...
# 3685233     1.171672         False          4          1.209032        False
# 3685234     1.171672         False          4          1.209032         True
# 3685235     1.171672         False          4          1.209032         True
# 3685236     1.171672         False          4          1.209032         True
# 3685237     1.171672         False          4          1.209032         True
#
#          parcel_bearing  road_bearing      angle  distance_to_road  \
# 0              1.073910      2.909873  74.807045         60.312846
# 1             -1.891185      2.909873  84.919612         46.654428
# 2              3.131970      2.909873  12.725181         88.951558
# 3             -0.452017      2.909873  12.622144         17.170511
# 4             -0.452017      2.909873  12.622144         17.170511
# ...                 ...           ...        ...               ...
# 3685233       -2.363794      0.756697   1.209032         12.578943
# 3685234       -0.797754      0.756697  89.063507         34.845350
# 3685235        0.772040      0.756697   0.879059         56.649433
# 3685236        2.343780      0.756697  89.066854         34.383025
# 3685237        2.343780      0.756697  89.066854         34.383025
#
#                   side                                           geometry
# 0        Interior side  LINESTRING (-97.45747 32.70121, -97.45711 32.7...
# 1        Interior side  LINESTRING (-97.45691 32.70169, -97.45710 32.7...
# 2                 rear  LINESTRING (-97.45710 32.70120, -97.45747 32.7...
# 3                front  LINESTRING (-97.45711 32.70177, -97.45709 32.7...
# 4             centroid                         POINT (-97.45716 32.70145)
# ...                ...                                                ...
# 3685233          front  LINESTRING (-97.40911 32.65291, -97.40928 32.6...
# 3685234  Interior side  LINESTRING (-97.40939 32.65315, -97.40911 32.6...
# 3685235           rear  LINESTRING (-97.40955 32.65302, -97.40939 32.6...
# 3685236  Interior side  LINESTRING (-97.40928 32.65278, -97.40955 32.6...
# 3685237       centroid                         POINT (-97.40933 32.65296)
#
# [3685238 rows x 20 columns]

# %%
# import geopandas as gpd

# def reproject_geojson_area(input_path, output_path, target_crs=4326):
#     """
#     Reads a GeoJSON file, reprojects it to the target CRS, and saves it.

#     Parameters:
#     -----------
#     input_path : str
#         Path to the input GeoJSON file.
#     output_path : str
#         Path to save the reprojected GeoJSON file.
#     target_crs : int or str, optional
#         EPSG code or PROJ string of the target CRS. Default is 4326 (WGS84).
#     """
#     gdf = gpd.read_file(input_path)
#     gdf = gdf.to_crs(target_crs)
#     gdf.to_file(output_path, driver='GeoJSON')
#     return gdf

# input_fp = r"C:\Users\Admin\Desktop\New folder (6)\Output_dataset\Tarrant_County_confidence_area.geojson"
# output_fp = r"C:\Users\Admin\Desktop\New folder (6)\Output_dataset\Tarrant_County_confidence_area.geojson"

# gdf_area = reproject_geojson_area(input_fp, output_fp)
# gdf_area
# Out:
#        parcel_id       parcel_addr landuse                parcel_label  \
# 0         326302  117 E BELKNAP ST     NaN       regular corner parcel
# 1         513461    1416 MICAH WAY       R          curve parcel_other
# 2         513472    1412 MICAH WAY       R       regular inside parcel
# 3         513474    1410 MICAH WAY       R     special parcel_standard
# 4         513475    1408 MICAH WAY       R       regular inside parcel
# ...          ...               ...     ...                         ...
# 684177    484603               NaN     NaN  no_address_parcel_standard
# 684178    616638               NaN     NaN  no_address_parcel_standard
# 684179   2317187               NaN     NaN     no_address_parcel_other
# 684180    156434               NaN     NaN  no_address_parcel_standard
# 684181    176305               NaN     NaN  no_address_parcel_standard
#
#        confidence_level  area_acre  \
# 0                   Yes   0.172734
# 1                    No   0.584770
# 2                   Yes   0.495700
# 3                   Yes   0.650363
# 4                   Yes   0.633756
# ...                 ...        ...
# 684177              Yes   0.305715
# 684178              Yes   0.546883
# 684179               No   0.271375
# 684180              Yes   1.377134
# 684181              Yes   0.263706
#
#                                                  geometry
# 0       POLYGON ((-97.33293 32.75815, -97.33309 32.758...
# 1       POLYGON ((-97.22169 32.92321, -97.22169 32.922...
# 2       POLYGON ((-97.22185 32.92251, -97.22188 32.922...
# 3       POLYGON ((-97.22207 32.92216, -97.22218 32.921...
# 4       POLYGON ((-97.22263 32.92231, -97.22239 32.921...
# ...                                                   ...
# 684177  POLYGON ((-97.19371 32.87888, -97.19371 32.879...
# 684178  POLYGON ((-97.07272 32.93913, -97.07272 32.938...
# 684179  POLYGON ((-97.21659 32.67466, -97.21640 32.674...
# 684180  POLYGON ((-97.20808 32.56851, -97.20815 32.568...
# 684181  POLYGON ((-97.17439 32.59126, -97.17468 32.591...
#
# [684182 rows x 7 columns]

# %%
# all_ids = pd.Series(
#     pd.concat([gdf_parcel['parcel_id'], gdf_area['parcel_id']]).unique()
# ).dropna().astype(str).sort_values().reset_index(drop=True)

# id_map = {pid: i+1 for i, pid in enumerate(all_ids)}
# gdf_parcel['parcel_id'] = gdf_parcel['parcel_id'].astype(str).map(id_map).astype(str)
# gdf_area['parcel_id'] = gdf_area['parcel_id'].astype(str).map(id_map).astype(str)

# %%
#
